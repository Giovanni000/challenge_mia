# %% [markdown]
# # 🏴‍☠️ AN2DL25 Challenge 1 — Pirate Pain Classification
#
# ## Overview
#
# This notebook implements a complete deep-learning pipeline for multivariate time-series classification of the Pirate Pain dataset. The solution is inspired by the Lecture 4 notebook (`Timeseries Classification (1).ipynb`) but adapted for the competition setting, including comprehensive data preparation, model training (RNN/GRU/LSTM variants), evaluation, and test-time inference.
#
# ## Table of Contents
#
# 1. **Environment Setup** - Library imports and configuration
# 2. **Data Loading** - Loading and initial inspection of the dataset
# 3. **Data Preprocessing** - Feature engineering, normalization, and cleaning
# 4. **Model Architecture** - Recurrent neural network implementations
# 5. **Training Pipeline** - Training loops, validation, and cross-validation
# 6. **Evaluation** - Metrics computation and visualization
# 7. **Inference** - Test set predictions and submission generation

# %% [markdown]
# ## 1. Environment Setup
#
# ### 1.1 Package Installation
#
# The following cell installs required dependencies (if needed). This is typically used in Google Colab environments.

# %% [markdown]
# ### 1.2 Library Imports
#
# Import all necessary libraries for data processing, machine learning, and visualization.

# %% [markdown]
# ### 1.3 Configuration and Paths Setup
#
# This section configures the working environment, including:
# - Setting random seeds for reproducibility
# - Detecting the execution environment (Google Colab vs local)
# - Setting up data and output directories
# - Configuring device (CPU/GPU) and mixed-precision training utilities
#
# **Note:** The code automatically detects the correct data directory path based on the execution environment.

# %%
# %%capture
# !pip install -q -r requirements.txt

# %% [markdown]
# ### 1.4 Output Directories
#
# Create directories for storing logs, checkpoints, and reports.

# %% [markdown]
# ## 2. Data Loading
#
# Load the training and test datasets from CSV files. The dataset consists of multivariate time-series data with multiple features recorded over time steps.

# %% [markdown]
# ## 3. Data Preprocessing
#
# ### 3.1 Data Profiling and Feature Diagnostics
#
# This section performs comprehensive feature analysis to understand the dataset characteristics:
# - **Descriptive statistics**: Mean, std, min, max for each feature
# - **Missing values**: Identification of missing data patterns
# - **Variance analysis**: Detection of low-variance features
# - **Correlation analysis**: Identification of highly correlated features
# - **Outlier detection**: Detection of features dominated by extreme values
#
# All diagnostic reports are saved to the `reports` directory for later analysis.

# %% [markdown]
# ### 3.2 Feature Engineering and Selection
#
# This section performs feature engineering and selection:
#
# 1. **Categorical encoding**: Maps categorical features (n_legs, n_hands, n_eyes) to integer indices
# 2. **Feature removal**: Removes features based on multiple criteria:
#    - Constant features (no variance)
#    - Low variance features
#    - Low magnitude features
#    - Highly correlated features (redundancy)
#    - Outlier-dominated features
# 3. **Temporal features**: Adds time-based features (fraction, sin/cos encoding, start/end indicators)
# 4. **Temporal statistics**: Computes rolling mean and standard deviation over different window sizes
#
# The feature removal process is logged for transparency and reproducibility.

# %%
import os
import random
import math
import copy
from pathlib import Path
from typing import Tuple, Dict, Optional, List, Any
from datetime import datetime
from itertools import product
import inspect

import numpy as np
import pandas as pd
from sklearn.metrics import (
    f1_score,
    classification_report,
    confusion_matrix,
    precision_recall_fscore_support,
)
from sklearn.model_selection import StratifiedKFold, train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

try:
    from torch.amp import autocast, GradScaler
except ImportError:  # pragma: no cover
    from torch.cuda.amp import autocast, GradScaler

# %% [markdown]
# ### 3.3 Data Consistency Checks
#
# Perform sanity checks to ensure data consistency between training and test sets, and verify that all feature columns are properly defined.

# %% [markdown]
# ### 3.4 Label Mapping and Class Imbalance Handling
#
# This section:
# - Creates mappings between class labels and integer indices
# - Identifies class groups (high pain, low pain, no pain) for targeted augmentation
# - Configures class weights and oversampling factors to handle class imbalance
# - Prepares data for training by converting time-series data to the required format
#
# The class imbalance is significant (56 high_pain, 94 low_pain, 511 no_pain), so we apply:
# - **Oversampling**: High-pain and low-pain classes are oversampled during training
# - **Class weights**: Adjusted weights in the loss function to penalize misclassification of minority classes
# - **Augmentation**: More aggressive augmentation for minority classes

# %%
SEED = 2024

try:
    from google.colab import drive  # type: ignore
    IN_COLAB = True
except ImportError:  # pragma: no cover
    IN_COLAB = False

if IN_COLAB:
    drive.mount('/content/drive', force_remount=False)
    BASE_DIR = Path('/content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge')
else:
    BASE_DIR = Path('/Users/md101ta/Desktop/Pirates')

DATA_DIR = (BASE_DIR / 'data').resolve()
# Immediately after defining DATA_DIR in cell 3
DATA_DIR_CANDIDATES = [
    Path('/content/drive/MyDrive/[2025-2026] AN2DL/Challenge'),
    Path('/content/drive/MyDrive/[2025-2026]\\ A2NDL/Challenge'),
    BASE_DIR / 'data'
]

for candidate in DATA_DIR_CANDIDATES:
    if candidate.exists():
        DATA_DIR = candidate
        break
else:
    raise FileNotFoundError('No valid DATA_DIR found')

print(f'Using DATA_DIR: {DATA_DIR}')
OUTPUT_DIR = (BASE_DIR / 'outputs').resolve()
OUTPUT_DIR.mkdir(exist_ok=True, parents=True)

# Reproducibility
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
    DEVICE = torch.device('cuda')
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
else:
    DEVICE = torch.device('cpu')

print(f'Running in Colab: {IN_COLAB}')
print(f'Device: {DEVICE}')
print(f'Data dir: {DATA_DIR}')
print(f'Output dir: {OUTPUT_DIR}')

_AUTocast_params = inspect.signature(autocast).parameters
_GRADSCALER_PARAMS = inspect.signature(GradScaler).parameters

def autocast_context():
    enabled = DEVICE.type == 'cuda'
    if 'device_type' in _AUTocast_params:
        return autocast(device_type=DEVICE.type, enabled=enabled)
    if 'device' in _AUTocast_params:
        return autocast(DEVICE.type, enabled=enabled)
    # fallback to legacy signature (enabled only)
    return autocast(enabled=enabled)


def create_grad_scaler():
    enabled = DEVICE.type == 'cuda'
    if 'device_type' in _GRADSCALER_PARAMS:
        return GradScaler(device_type=DEVICE.type, enabled=enabled)
    return GradScaler(enabled=enabled)
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\ '
# <>:11: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-1665548672.py:11: SyntaxWarning: invalid escape sequence '\ '
#   BASE_DIR = Path('/content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge')
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Usando DATA_DIR: /content/drive/MyDrive/[2025-2026] AN2DL/Challenge
# Running in Colab: True
# Device: cuda
# Data dir: /content/drive/MyDrive/[2025-2026] AN2DL/Challenge
# Output dir: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs

# %% [markdown]
# ### 3.5 Class Weights Computation
#
# Compute class weights for the loss function to handle class imbalance. The weights are normalized and scaled based on class importance.

# %% [markdown]
# ### 3.6 Data Normalization
#
# Normalize the features using z-score normalization (mean=0, std=1). The normalization statistics are computed only on the training set and then applied to both training and test sets to prevent data leakage.

# %%
LOG_DIR = (OUTPUT_DIR / 'logs').resolve()
CHECKPOINT_DIR = (OUTPUT_DIR / 'checkpoints').resolve()
LOG_DIR.mkdir(exist_ok=True, parents=True)
CHECKPOINT_DIR.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# ## 4. Model Architecture and Training Components
#
# ### 4.1 DataLoader Factory
#
# Utility function to create DataLoaders with appropriate configurations for training, validation, and testing.

# %% [markdown]
# ### 4.2 Time Series Dataset Class
#
# Custom PyTorch Dataset class that handles:
# - **Sliding windows**: Extracts windows of specified size from time series during training
# - **Oversampling**: Duplicates samples from minority classes (high-pain)
# - **Data augmentation**: Applies various augmentation techniques for high-pain samples:
#   - **Jittering**: Adds Gaussian noise
#   - **Scaling**: Random scaling within a range
#   - **Time shifting**: Circular shifts along the time dimension
#   - **Time flipping**: Reverses the temporal order
#   - **Time masking**: Randomly masks portions of the time series
#
# The augmentation is only applied during training and only to high-pain samples to increase their representation.

# %%
from typing import Tuple

assert DATA_DIR.exists(), f"DATA_DIR does not exist: {DATA_DIR}"

def load_data(data_dir: Path) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    X_train = pd.read_csv(data_dir / 'pirate_pain_train.csv')
    y_train = pd.read_csv(data_dir / 'pirate_pain_train_labels.csv')
    X_test  = pd.read_csv(data_dir / 'pirate_pain_test.csv')
    return X_train, y_train, X_test

# Load the data
X_train_raw, y_train, X_test_raw = load_data(DATA_DIR)
print(X_train_raw.shape, y_train.shape, X_test_raw.shape)
# Out:
# (105760, 40) (661, 2) (211840, 40)

# %% [markdown]
# ### 4.3 Loss Functions and Utilities
#
# This section implements:
# - **Focal Loss**: A loss function that focuses learning on hard examples, particularly useful for imbalanced datasets
# - **Loss function builder**: Factory function to create loss functions based on configuration
# - **Sliding window inference**: Functions to extract multiple windows from a time series and aggregate predictions (max, mean, or logsumexp)
#
# The focal loss helps the model focus on difficult-to-classify examples, which is crucial for minority classes.

# %% [markdown]
# ### 4.4 DataLoader Creation
#
# Create training and validation DataLoaders with the specified batch size and data augmentation settings.

# %%
# -- Data profiling & feature diagnostics -------------------------------------------------
REPORT_DIR = (OUTPUT_DIR / 'reports').resolve()
REPORT_DIR.mkdir(exist_ok=True, parents=True)

X_train_raw = X_train_raw.sort_values(['sample_index', 'time']).reset_index(drop=True)
X_test_raw = X_test_raw.sort_values(['sample_index', 'time']).reset_index(drop=True)

FEATURE_BASE_COLUMNS = [col for col in X_train_raw.columns if col not in ['sample_index', 'time']]
NUMERIC_FEATURE_BASE_COLUMNS = X_train_raw[FEATURE_BASE_COLUMNS].select_dtypes(include=[np.number]).columns.tolist()
feature_audit_entries: List[Dict[str, Any]] = []

if not NUMERIC_FEATURE_BASE_COLUMNS:
    raise RuntimeError('No numeric features found for profiling. Check data loading.')

def save_report(df: pd.DataFrame, filename: str):
    output_path = REPORT_DIR / filename
    df.to_csv(output_path)
    print(f"Saved report: {output_path}")

# Descriptive statistics
feature_describe = X_train_raw[NUMERIC_FEATURE_BASE_COLUMNS].describe().T
save_report(feature_describe, 'feature_describe.csv')

# Missing values
missing_info = pd.DataFrame({
    'missing_count': X_train_raw[FEATURE_BASE_COLUMNS].isna().sum(),
    'missing_ratio': X_train_raw[FEATURE_BASE_COLUMNS].isna().mean(),
})
save_report(missing_info, 'feature_missing.csv')

# Variance
variance_info = X_train_raw[NUMERIC_FEATURE_BASE_COLUMNS].var().to_frame(name='variance')
save_report(variance_info, 'feature_variance.csv')

# Correlations (absolute values)
corr_matrix = X_train_raw[NUMERIC_FEATURE_BASE_COLUMNS].corr().abs()
save_report(corr_matrix, 'feature_correlation.csv')

# Outlier ratio (values beyond 5 sigma)
feature_means = X_train_raw[NUMERIC_FEATURE_BASE_COLUMNS].mean()
feature_stds = X_train_raw[NUMERIC_FEATURE_BASE_COLUMNS].std() + 1e-8
z_scores = np.abs((X_train_raw[NUMERIC_FEATURE_BASE_COLUMNS] - feature_means) / feature_stds)
outlier_ratio = (z_scores > 5).sum().div(len(X_train_raw)).to_frame(name='outlier_ratio')
save_report(outlier_ratio, 'feature_outlier_ratio.csv')

print('Profiling completed. Total features analyzed:', len(FEATURE_BASE_COLUMNS))
# Out:
# Salvato report: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/reports/feature_describe.csv
# Salvato report: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/reports/feature_missing.csv
# Salvato report: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/reports/feature_variance.csv
# Salvato report: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/reports/feature_correlation.csv
# Salvato report: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/reports/feature_outlier_ratio.csv
# Profiling completato. Totale feature analizzate: 38

# %% [markdown]
# ### 4.5 Recurrent Neural Network Architecture
#
# The `RecurrentBackbone` class implements a flexible RNN-based architecture:
#
# - **Optional 1D Convolutional layers**: Pre-processes the input before the RNN
# - **RNN layer**: Supports RNN, GRU, or LSTM with configurable:
#   - Hidden size
#   - Number of layers
#   - Bidirectional processing
#   - Dropout regularization
# - **Classification head**: Fully connected layers with dropout for final classification
#
# The architecture can process sequences bidirectionally, allowing the model to use both past and future context when making predictions.

# %% [markdown]
# ### 4.6 Training and Evaluation Functions
#
# This section implements:
# - **Metric computation**: Calculates accuracy, precision, recall, and F1-score
# - **Training loop**: One epoch of training with mixed-precision support and gradient clipping
# - **Evaluation loop**: Evaluates the model on validation/test data with sliding window aggregation
#
# The training uses:
# - **Mixed precision**: Accelerates training on GPUs while maintaining numerical stability
# - **Gradient clipping**: Prevents exploding gradients
# - **Sliding window aggregation**: During evaluation, multiple windows are extracted and predictions are aggregated

# %% [markdown]
# ### 4.7 Model Training Function
#
# The `fit_model` function orchestrates the complete training process:
# - Model initialization
# - Optimizer and learning rate scheduler setup
# - Training loop with early stopping
# - Best model checkpointing
# - TensorBoard logging for visualization
#
# **Key features:**
# - **Early stopping**: Stops training if validation F1-score doesn't improve for a specified number of epochs
# - **Learning rate scheduling**: Reduces learning rate when validation performance plateaus
# - **Checkpointing**: Saves the best model based on validation F1-score
# - **Comprehensive logging**: Tracks all metrics and learning rates

# %% [markdown]
# ### 4.8 Cross-Validation Function
#
# Implements k-fold stratified cross-validation to get robust performance estimates. Each fold trains a separate model and evaluates on a held-out validation set.

# %% [markdown]
# ### 4.9 Results Summarization
#
# Utility functions to aggregate and summarize results from multiple experiments and cross-validation folds.

# %% [markdown]
# ### 4.10 Experiment Configuration and Execution
#
# Functions to prepare experiment configurations and execute training experiments. The configuration system allows easy experimentation with different hyperparameters.

# %% [markdown]
# ## 5. Model Training
#
# ### 5.1 Experiment Execution
#
# Run experiments with different model configurations. This cell trains:
# - **GRU_BI**: Bidirectional GRU model
# - **GRU_SINGLE**: Unidirectional GRU model
#
# After initial experiments, the best configuration is selected for cross-validation to get robust performance estimates.

# %% [markdown]
# ### 5.2 Results Summary
#
# Aggregate and display results from all experiments and cross-validation folds. The summary table shows performance metrics for each run, sorted by F1-score.

# %% [markdown]
# ### 5.3 Cross-Validation Summary
#
# Display aggregated statistics from cross-validation, showing mean and standard deviation of metrics across folds.

# %% [markdown]
# ### 5.4 Best Model Selection
#
# Select the best model based on validation F1-score from all experiments and cross-validation folds.

# %% [markdown]
# ## 6. Evaluation and Visualization
#
# ### 6.1 Learning Curves
#
# Visualize the training and validation metrics over epochs to assess model convergence and detect overfitting.

# %% [markdown]
# ### 6.2 Classification Report and Confusion Matrix
#
# Display detailed classification metrics and confusion matrix for the best model on the validation set. This provides insights into:
# - Per-class performance (precision, recall, F1-score)
# - Confusion patterns between classes
# - Overall accuracy

# %% [markdown]
# ## 7. Inference and Submission
#
# ### 7.1 Test Set Predictions
#
# Generate predictions on the test set using the best model. The inference uses sliding window aggregation to make robust predictions by considering multiple temporal windows from each test sample.

# %% [markdown]
# ### 7.2 TensorBoard Visualization
#
# Launch TensorBoard to visualize training metrics, loss curves, and other logged information. This is useful for analyzing training dynamics and comparing different runs.
#
# **Note:** This cell may produce an error if TensorBoard is not available in the current environment. The logs can still be viewed by running TensorBoard separately.

# %%
CATEGORICAL_COLUMNS = ['n_legs', 'n_hands', 'n_eyes']
CATEGORY_MAPPINGS: Dict[str, Dict[str, int]] = {}

for col in CATEGORICAL_COLUMNS:
    uniques = pd.concat([X_train_raw[col], X_test_raw[col]]).dropna().unique()
    mapping = {value: idx for idx, value in enumerate(sorted(uniques))}
    CATEGORY_MAPPINGS[col] = mapping
    X_train_raw[col] = X_train_raw[col].map(mapping).astype(np.int32)
    X_test_raw[col] = X_test_raw[col].map(mapping).astype(np.int32)

FEATURE_COLUMNS = [col for col in X_train_raw.columns if col not in ['sample_index', 'time']]

LOW_VARIANCE_THRESHOLD = 2e-3
LOW_MAG_THRESHOLD = 1e-3
HIGH_CORR_THRESHOLD = 0.98

feature_std = X_train_raw[FEATURE_COLUMNS].std()
feature_abs_max = X_train_raw[FEATURE_COLUMNS].abs().max()

# Helper function to log removed features

def log_feature_removal(feature: str, reason: str, metric_value: Optional[float] = None, notes: Optional[str] = None):
    entry = {
        'feature': feature,
        'reason': reason,
        'metric': metric_value,
        'notes': notes,
    }
    feature_audit_entries.append(entry)

# Constant columns
constant_features = [col for col in FEATURE_COLUMNS if X_train_raw[col].nunique(dropna=False) <= 1]
for feature in constant_features:
    log_feature_removal(feature, 'constant_value', X_train_raw[feature].iloc[0])

# Low variance
low_variance = feature_std[feature_std <= LOW_VARIANCE_THRESHOLD]
for feature, value in low_variance.items():
    log_feature_removal(feature, 'low_variance', float(value))

# Low magnitude
low_magnitude = feature_abs_max[feature_abs_max <= LOW_MAG_THRESHOLD]
for feature, value in low_magnitude.items():
    log_feature_removal(feature, 'low_magnitude', float(value))

# High correlation
corr_matrix = X_train_raw[FEATURE_COLUMNS].corr().abs()
upper_mask = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)
upper_corr = corr_matrix.where(upper_mask)
high_corr_features = set()
for col in upper_corr.columns:
    partners = upper_corr.index[upper_corr[col] >= HIGH_CORR_THRESHOLD].tolist()
    if partners:
        high_corr_features.add(col)
        joined_partners = ','.join(partners)
        log_feature_removal(col, 'high_correlation', notes=f'correlated_with={joined_partners}')

# Outlier-dominated features (optional, conservative threshold)
outlier_flagged = outlier_ratio[outlier_ratio['outlier_ratio'] >= 0.75].index.tolist()
for feature in outlier_flagged:
    log_feature_removal(feature, 'extreme_outliers', float(outlier_ratio.loc[feature, 'outlier_ratio']))

features_to_drop = sorted(set(constant_features) | set(low_variance.index) | set(low_magnitude.index) | high_corr_features | set(outlier_flagged))
if features_to_drop:
    print("Removing features:", features_to_drop)
    X_train_raw = X_train_raw.drop(columns=features_to_drop)
    X_test_raw = X_test_raw.drop(columns=features_to_drop)
    FEATURE_COLUMNS = [col for col in FEATURE_COLUMNS if col not in features_to_drop]

    removal_df = pd.DataFrame(feature_audit_entries)
    if not removal_df.empty:
        save_report(removal_df, 'feature_removal_log.csv')
else:
    print('No features removed with the specified criteria.')
    removal_df = pd.DataFrame(feature_audit_entries)
    save_report(removal_df, 'feature_removal_log.csv')

FULL_TIME_STEPS = X_train_raw['time'].nunique()
WINDOW_SIZE = 25
WINDOW_STRIDE = 15
EVAL_WINDOW_SIZE = WINDOW_SIZE
EVAL_WINDOW_STRIDE = WINDOW_STRIDE
EVAL_AGGREGATION = 'logsumexp'
if WINDOW_SIZE > FULL_TIME_STEPS:
    raise ValueError(
        f'Requested window size ({WINDOW_SIZE}) exceeds the available time steps ({FULL_TIME_STEPS}).'
    )
TIME_STEPS = FULL_TIME_STEPS

TIME_DIVISOR = max(FULL_TIME_STEPS - 1, 1)
TIME_FEATURE_COLUMNS = ['time_fraction', 'time_sin', 'time_cos', 'time_is_start', 'time_is_end']
for df in (X_train_raw, X_test_raw):
    frac = (df['time'] / TIME_DIVISOR).astype(np.float32)
    df['time_fraction'] = frac
    df['time_sin'] = np.sin(2 * np.pi * frac).astype(np.float32)
    df['time_cos'] = np.cos(2 * np.pi * frac).astype(np.float32)
    df['time_is_start'] = (df['time'] == 0).astype(np.float32)
    df['time_is_end'] = (df['time'] == FULL_TIME_STEPS - 1).astype(np.float32)

for col in TIME_FEATURE_COLUMNS:
    if col not in FEATURE_COLUMNS:
        FEATURE_COLUMNS.append(col)

TEMPORAL_WINDOW_SIZES = (5, 15)
VALUE_FEATURE_COLUMNS = [col for col in FEATURE_COLUMNS if col not in (TIME_FEATURE_COLUMNS + CATEGORICAL_COLUMNS)]

def add_temporal_statistics(df: pd.DataFrame):
    if not VALUE_FEATURE_COLUMNS:
        return
    df_signal = df[VALUE_FEATURE_COLUMNS].abs().mean(axis=1)
    df['signal_abs_mean'] = df_signal
    if 'signal_abs_mean' not in FEATURE_COLUMNS:
        FEATURE_COLUMNS.append('signal_abs_mean')
    for window in TEMPORAL_WINDOW_SIZES:
        rolling_mean = (
            df.groupby('sample_index')['signal_abs_mean']
              .transform(lambda x: x.rolling(window, min_periods=1, center=True).mean())
        )
        rolling_std = (
            df.groupby('sample_index')['signal_abs_mean']
              .transform(lambda x: x.rolling(window, min_periods=1, center=True).std().fillna(0.0))
        )
        df[f'signal_mean_w{window}'] = rolling_mean
        df[f'signal_std_w{window}'] = rolling_std
        for feature in (f'signal_mean_w{window}', f'signal_std_w{window}'):
            if feature not in FEATURE_COLUMNS:
                FEATURE_COLUMNS.append(feature)

for dataset in (X_train_raw, X_test_raw):
    add_temporal_statistics(dataset)

NUM_FEATURES = len(FEATURE_COLUMNS)
NUM_CLASSES = y_train['label'].nunique()
print(
    f'Time steps (raw): {FULL_TIME_STEPS} | Window size: {WINDOW_SIZE} | Features: {NUM_FEATURES} | Classes: {NUM_CLASSES}'
)
print('Category mappings:', CATEGORY_MAPPINGS)

y_train['label'].value_counts().plot(kind='bar', title='Class distribution')
plt.show()
# Out:
# Removing features: ['joint_13', 'joint_14', 'joint_15', 'joint_16', 'joint_23', 'joint_24', 'joint_30', 'n_eyes', 'n_hands']
# Salvato report: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/reports/feature_removal_log.csv
# Time steps (raw): 160 | Window size: 25 | Features: 39 | Classes: 3
# Category mappings: {'n_legs': {'one+peg_leg': 0, 'two': 1}, 'n_hands': {'one+hook_hand': 0, 'two': 1}, 'n_eyes': {'one+eye_patch': 0, 'two': 1}}

# %%
# -- Sanity checks to ensure pipeline consistency ---------------------------
def run_quick_sanity_checks():
    train_cols = set(X_train_raw.columns)
    test_cols = set(X_test_raw.columns)
    assert train_cols == test_cols, 'Train/Test have different columns'
    assert len(FEATURE_COLUMNS) == len(set(FEATURE_COLUMNS)), 'FEATURE_COLUMNS contains duplicates'
    assert all(col in train_cols for col in FEATURE_COLUMNS), 'Feature columns not present in dataset'
    assert NUM_FEATURES == len(FEATURE_COLUMNS), 'NUM_FEATURES not aligned'
    print('Sanity checks passed: dataset and feature set are consistent.')

run_quick_sanity_checks()
# Out:
# Sanity checks superati: dataset e feature set coerenti.

# %%
LABEL2IDX = {label: idx for idx, label in enumerate(sorted(y_train['label'].unique()))}
IDX2LABEL = {idx: label for label, idx in LABEL2IDX.items()}
print('Label mapping:', LABEL2IDX)

HIGH_PAIN_LABELS = [label for label in LABEL2IDX if 'high' in label.lower()]
LOW_PAIN_LABELS = [label for label in LABEL2IDX if 'low' in label.lower()]
NO_PAIN_LABELS = [label for label in LABEL2IDX if 'no' in label.lower()]
HIGH_PAIN_IDX = {LABEL2IDX[label] for label in HIGH_PAIN_LABELS}
LOW_PAIN_IDX = {LABEL2IDX[label] for label in LOW_PAIN_LABELS}
NO_PAIN_IDX = {LABEL2IDX[label] for label in NO_PAIN_LABELS}
print('High-pain classes for augmentation:', HIGH_PAIN_LABELS or 'None')
print('Low-pain classes for augmentation:', LOW_PAIN_LABELS or 'None')
print('No-pain classes for augmentation:', NO_PAIN_IDX or 'None')

HIGH_PAIN_OVERSAMPLE = 2 if HIGH_PAIN_IDX else 1
LOW_PAIN_OVERSAMPLE = 2 if LOW_PAIN_IDX else 1
HIGH_PAIN_WEIGHT_SCALE = 0.25
LOW_PAIN_WEIGHT_SCALE = 0.45
NO_PAIN_WEIGHT_SCALE = 1.9
HIGH_PAIN_AUGMENTATION_PARAMS = {
    'jitter_std': 0.03,
    'scale_range': (0.90, 1.10),
    'time_mask_prob': 0.30,
    'time_mask_ratio': 0.12,
    'time_shift_range': 4,
    'time_flip_prob': 0.10,
}
LOW_PAIN_AUGMENTATION_PARAMS = {
    'jitter_std': 0.02,
    'scale_range': (0.95, 1.05),
    'time_mask_prob': 0.20,
    'time_mask_ratio': 0.08,
    'time_shift_range': 3,
    'time_flip_prob': 0.05,
}
AUGMENTATION_PARAMS = HIGH_PAIN_AUGMENTATION_PARAMS


def pivot_timeseries(df: pd.DataFrame) -> np.ndarray:
    pivoted = (
        df.pivot(index='sample_index', columns='time', values=FEATURE_COLUMNS)
          .sort_index(axis=0)
          .sort_index(axis=1, level=1)
    )
    data = pivoted.to_numpy().reshape(-1, TIME_STEPS, NUM_FEATURES)
    return data


X_train_np = pivot_timeseries(X_train_raw)
X_test_np = pivot_timeseries(X_test_raw)
y_train_idx = y_train.set_index('sample_index').loc[pd.unique(X_train_raw['sample_index'])]['label'].map(LABEL2IDX).to_numpy()

print(X_train_np.shape, y_train_idx.shape, X_test_np.shape)
# Out:
# Label mapping: {'high_pain': 0, 'low_pain': 1, 'no_pain': 2}
# High-pain classes for augmentation: ['high_pain']
# Low-pain classes for augmentation: ['low_pain']
# No-pain classes for augmentation: {2}
# (661, 160, 39) (661,) (1324, 160, 39)

# %%
class_counts = np.bincount(y_train_idx, minlength=NUM_CLASSES)
class_weights = class_counts.sum() / (class_counts + 1e-6)
class_weights = class_weights / class_weights.mean()
if HIGH_PAIN_IDX:
    for idx in HIGH_PAIN_IDX:
        class_weights[idx] *= HIGH_PAIN_WEIGHT_SCALE
if LOW_PAIN_IDX:
    for idx in LOW_PAIN_IDX:
        class_weights[idx] *= LOW_PAIN_WEIGHT_SCALE
if NO_PAIN_IDX:
    for idx in NO_PAIN_IDX:
        class_weights[idx] *= NO_PAIN_WEIGHT_SCALE
CLASS_COUNTS = class_counts
CLASS_WEIGHTS = torch.tensor(class_weights, dtype=torch.float32)
print('Class counts:', class_counts)
print('Class weights (normalized):', np.round(class_weights, 3))
# Out:
# Class counts: [ 56  94 511]
# Class weights (normalized): [0.484 0.472 0.366]

# %%
def compute_normalization_stats(data: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    # data shape: (N, T, F)
    mean = data.reshape(-1, NUM_FEATURES).mean(axis=0)
    std = data.reshape(-1, NUM_FEATURES).std(axis=0) + 1e-6
    return mean, std


def normalize(data: np.ndarray, mean: np.ndarray, std: np.ndarray) -> np.ndarray:
    return (data - mean) / std


feat_mean, feat_std = compute_normalization_stats(X_train_np)
X_train_np = normalize(X_train_np, feat_mean, feat_std)
X_test_np = normalize(X_test_np, feat_mean, feat_std)

# %%
def make_dataloader_from_arrays(
    X: np.ndarray,
    y: Optional[np.ndarray],
    batch_size: int,
    shuffle: bool,
    mode: str,
    oversample_factor: int = 1,
    augmentation_params: Optional[Dict[str, float]] = None,
    window_size: Optional[int] = None,
    window_stride: Optional[int] = None,
) -> DataLoader:
    dataset = TimeSeriesDataset(
        X,
        y,
        window_size=window_size,
        window_stride=window_stride,
        mode=mode,
        high_pain_targets=HIGH_PAIN_IDX,
        oversample_factor=oversample_factor,
        augmentation_params=augmentation_params,
    )
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, drop_last=False)

# %%
class TimeSeriesDataset(Dataset):
    def __init__(
        self,
        data: np.ndarray,
        labels: Optional[np.ndarray] = None,
        *,
        window_size: Optional[int] = None,
        window_stride: Optional[int] = None,
        mode: str = 'train',
        high_pain_targets: Optional[set] = None,
        oversample_factor: int = 1,
        augmentation_params: Optional[Dict[str, float]] = None,
    ):
        self.data = torch.tensor(data, dtype=torch.float32)
        self.labels = None if labels is None else torch.tensor(labels, dtype=torch.long)
        self.window_size = window_size
        self.window_stride = max(1, window_stride or 1)
        self.mode = mode
        self.high_pain_targets = set(high_pain_targets or [])
        self.augmentation_params = augmentation_params or {}
        self.time_steps = self.data.shape[1]

        if mode not in {'train', 'valid', 'test'}:
            raise ValueError(f"Unsupported mode '{mode}'. Use 'train', 'valid', or 'test'.")
        if self.window_size is not None and self.window_size > self.time_steps:
            raise ValueError(
                f'Window size {self.window_size} exceeds series length {self.time_steps}.'
            )

        self.indices = self._build_indices(max(1, oversample_factor))

    def _build_indices(self, oversample_factor: int) -> List[int]:
        base_indices = list(range(len(self.data)))
        if (
            self.labels is None
            or not self.high_pain_targets
            or oversample_factor <= 1
        ):
            return base_indices

        high_indices = [idx for idx in base_indices if int(self.labels[idx].item()) in self.high_pain_targets]
        if not high_indices:
            return base_indices

        extra_indices: List[int] = []
        for _ in range(oversample_factor - 1):
            extra_indices.extend(high_indices)
        return base_indices + extra_indices

    def __len__(self) -> int:
        return len(self.indices)

    def __getitem__(self, idx: int):
        real_idx = self.indices[idx]
        series = self.data[real_idx]
        label = None if self.labels is None else self.labels[real_idx]

        if self.window_size is not None and self.mode == 'train':
            series = self._select_window(series, random_selection=True)
        elif self.window_size is not None and self.mode != 'train':
            series = self._select_window(series, random_selection=False)
        else:
            series = series.clone()

        if (
            self.mode == 'train'
            and label is not None
            and int(label.item()) in self.high_pain_targets
            and self.augmentation_params
        ):
            series = self._augment(series)

        if label is None:
            return series
        return series, label

    def _select_window(self, series: torch.Tensor, *, random_selection: bool) -> torch.Tensor:
        window = self.window_size or series.shape[0]
        if window >= series.shape[0]:
            return series.clone()

        max_start = series.shape[0] - window
        if max_start <= 0:
            start = 0
        else:
            stride = max(1, self.window_stride)
            positions = list(range(0, max_start + 1, stride))
            if positions[-1] != max_start:
                positions.append(max_start)
            if random_selection:
                start = random.choice(positions)
            else:
                start = positions[len(positions) // 2]
        end = start + window
        return series[start:end].clone()

    def _augment(self, series: torch.Tensor) -> torch.Tensor:
        augmented = series.clone()
        jitter_std = float(self.augmentation_params.get('jitter_std', 0.0))
        if jitter_std > 0:
            augmented = augmented + torch.randn_like(augmented) * jitter_std

        scale_range = self.augmentation_params.get('scale_range')
        if scale_range:
            low, high = scale_range
            scale = random.uniform(low, high)
            augmented = augmented * scale

        time_shift_range = int(self.augmentation_params.get('time_shift_range', 0))
        if time_shift_range > 0:
            shift = random.randint(-time_shift_range, time_shift_range)
            if shift != 0:
                augmented = torch.roll(augmented, shifts=shift, dims=0)

        if random.random() < float(self.augmentation_params.get('time_flip_prob', 0.0)):
            augmented = torch.flip(augmented, dims=[0])

        time_mask_prob = float(self.augmentation_params.get('time_mask_prob', 0.0))
        time_mask_ratio = float(self.augmentation_params.get('time_mask_ratio', 0.0))
        if time_mask_prob > 0 and time_mask_ratio > 0 and random.random() < time_mask_prob:
            mask_len = max(1, int(augmented.shape[0] * time_mask_ratio))
            if mask_len < augmented.shape[0]:
                start = random.randint(0, augmented.shape[0] - mask_len)
                augmented[start:start + mask_len] = 0.0

        return augmented

# %%
class FocalLoss(nn.Module):
    def __init__(
        self,
        weight: Optional[torch.Tensor] = None,
        gamma: float = 2.0,
        reduction: str = 'mean',
    ):
        super().__init__()
        if reduction not in {'none', 'mean', 'sum'}:
            raise ValueError(f"Unsupported reduction '{reduction}'.")
        if weight is not None:
            self.register_buffer('weight', weight)
            self._use_weight = True
        else:
            self.register_buffer('weight', torch.tensor([], dtype=torch.float32), persistent=False)
            self._use_weight = False
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
        if logits.shape[0] != targets.shape[0]:
            raise ValueError('Logits and targets must have matching batch dimension.')
        targets = targets.long().unsqueeze(1)
        log_probs = F.log_softmax(logits, dim=-1)
        probs = log_probs.exp()
        log_pt = log_probs.gather(1, targets)
        pt = probs.gather(1, targets).clamp(min=1e-6, max=1.0)
        focal_factor = (1.0 - pt) ** self.gamma
        loss = -focal_factor * log_pt
        if self._use_weight:
            class_weights = self.weight[targets.squeeze(1)]
            loss = loss * class_weights.unsqueeze(1)
        loss = loss.squeeze(1)
        if self.reduction == 'mean':
            return loss.mean()
        if self.reduction == 'sum':
            return loss.sum()
        return loss


def build_loss_fn(config: Dict) -> nn.Module:
    loss_type = config.get('loss_type', 'focal')
    use_class_weights = config.get('use_class_weights', True)
    weight_tensor = None
    if use_class_weights and 'CLASS_WEIGHTS' in globals():
        weight_tensor = CLASS_WEIGHTS.to(DEVICE)
    if loss_type == 'focal':
        gamma = config.get('focal_gamma', 2.0)
        return FocalLoss(weight=weight_tensor, gamma=gamma)
    if loss_type == 'weighted_ce':
        return nn.CrossEntropyLoss(weight=weight_tensor)
    if loss_type == 'cross_entropy':
        return nn.CrossEntropyLoss()
    raise ValueError(f"Unsupported loss_type '{loss_type}'.")


def extract_sliding_windows(
    series: torch.Tensor,
    window_size: Optional[int],
    stride: Optional[int],
) -> torch.Tensor:
    if window_size is None or window_size >= series.shape[0]:
        return series.unsqueeze(0)
    stride = max(1, stride or 1)
    length = series.shape[0]
    max_start = max(0, length - window_size)
    positions = list(range(0, max_start + 1, stride))
    if positions[-1] != max_start:
        positions.append(max_start)
    windows = [series[start:start + window_size] for start in positions]
    return torch.stack(windows, dim=0)


def forward_with_sliding_windows(
    model: nn.Module,
    inputs: torch.Tensor,
    window_size: Optional[int],
    stride: Optional[int],
    aggregation: str = 'max',
) -> torch.Tensor:
    if window_size is None or window_size >= inputs.shape[1]:
        return model(inputs)

    all_windows: List[torch.Tensor] = []
    window_counts: List[int] = []
    for sample in inputs:
        sample_windows = extract_sliding_windows(sample, window_size, stride)
        all_windows.append(sample_windows)
        window_counts.append(sample_windows.shape[0])

    stacked_windows = torch.cat(all_windows, dim=0)
    logits = model(stacked_windows)
    chunks = logits.split(window_counts, dim=0)

    aggregated_logits: List[torch.Tensor] = []
    aggregation = aggregation.lower()
    for chunk in chunks:
        if aggregation == 'max':
            aggregated_logits.append(chunk.max(dim=0).values)
        elif aggregation == 'mean':
            aggregated_logits.append(chunk.mean(dim=0))
        elif aggregation == 'logsumexp':
            aggregated_logits.append(torch.logsumexp(chunk, dim=0))
        else:
            raise ValueError(f"Unsupported aggregation '{aggregation}'.")

    return torch.stack(aggregated_logits, dim=0)

# %%
def create_dataloaders(
    X: np.ndarray,
    y: np.ndarray,
    valid_size: float = 0.2,
    batch_size: int = 128,
    oversample_factor: int = HIGH_PAIN_OVERSAMPLE,
    window_size: Optional[int] = WINDOW_SIZE,
    window_stride: Optional[int] = WINDOW_STRIDE,
    augmentation_params: Optional[Dict[str, float]] = AUGMENTATION_PARAMS,
):
    X_train, X_valid, y_train, y_valid = train_test_split(
        X, y, test_size=valid_size, random_state=SEED, stratify=y
    )

    train_loader = make_dataloader_from_arrays(
        X_train,
        y_train,
        batch_size=batch_size,
        shuffle=True,
        mode='train',
        oversample_factor=oversample_factor,
        augmentation_params=augmentation_params,
        window_size=window_size,
        window_stride=window_stride,
    )
    valid_loader = make_dataloader_from_arrays(
        X_valid,
        y_valid,
        batch_size=batch_size,
        shuffle=False,
        mode='valid',
        window_size=None,
        window_stride=None,
    )
    return train_loader, valid_loader, (X_train, y_train, X_valid, y_valid)


BATCH_SIZE = 128
train_loader, valid_loader, (X_train_split, y_train_split, X_valid_split, y_valid_split) = create_dataloaders(
    X_train_np,
    y_train_idx,
    batch_size=BATCH_SIZE,
)

# %%
class RecurrentBackbone(nn.Module):
    def __init__(
        self,
        input_size: int,
        hidden_size: int = 128,
        num_layers: int = 2,
        dropout: float = 0.2,
        rnn_type: str = 'lstm',
        bidirectional: bool = True,
        conv_layers: int = 0,
        conv_channels: Optional[int] = None,
        conv_kernel_size: int = 3,
        conv_dropout: float = 0.1,
    ):
        super().__init__()
        if conv_kernel_size % 2 == 0:
            raise ValueError('conv_kernel_size should be odd to preserve temporal dimension.')
        rnn_cls = {
            'rnn': nn.RNN,
            'gru': nn.GRU,
            'lstm': nn.LSTM,
        }[rnn_type.lower()]
        self.rnn_type = rnn_type.lower()
        self.bidirectional = bidirectional

        self.conv_layers = conv_layers
        self.conv = None
        rnn_input_size = input_size
        if conv_layers > 0:
            conv_blocks: List[nn.Module] = []
            in_channels = input_size
            out_channels = conv_channels or input_size
            for layer_idx in range(conv_layers):
                conv_blocks.append(
                    nn.Conv1d(
                        in_channels,
                        out_channels,
                        kernel_size=conv_kernel_size,
                        padding=conv_kernel_size // 2,
                        bias=False,
                    )
                )
                conv_blocks.append(nn.BatchNorm1d(out_channels))
                conv_blocks.append(nn.ReLU())
                if conv_dropout > 0:
                    conv_blocks.append(nn.Dropout(conv_dropout))
                in_channels = out_channels
            self.conv = nn.Sequential(*conv_blocks)
            rnn_input_size = out_channels

        self.rnn = rnn_cls(
            input_size=rnn_input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            dropout=dropout if num_layers > 1 else 0.0,
            batch_first=True,
            bidirectional=bidirectional,
        )
        proj_input = hidden_size * (2 if bidirectional else 1)
        self.head = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(proj_input, hidden_size),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_size, NUM_CLASSES),
        )

    def forward(self, x):
        if self.conv is not None:
            # (batch, time, feature) -> (batch, feature, time)
            x = x.transpose(1, 2)
            x = self.conv(x)
            x = x.transpose(1, 2)
        out, _ = self.rnn(x)
        # use last time-step hidden state
        last = out[:, -1, :]
        return self.head(last)

# %%
def compute_classification_metrics(preds: np.ndarray, targets: np.ndarray) -> Dict[str, float]:
    accuracy = float((preds == targets).mean())
    precision, recall, f1, _ = precision_recall_fscore_support(
        targets,
        preds,
        average='macro',
        zero_division=0,
    )
    return {
        'accuracy': accuracy,
        'precision': float(precision),
        'recall': float(recall),
        'f1': float(f1),
    }


def train_one_epoch(
    model: nn.Module,
    loader: DataLoader,
    criterion: nn.Module,
    optimizer: torch.optim.Optimizer,
    scaler: GradScaler,
    max_grad_norm: float = 5.0,
) -> Tuple[float, Dict[str, float]]:
    model.train()
    running_loss = 0.0
    preds_all, targets_all = [], []

    for inputs, targets in loader:
        inputs = inputs.to(DEVICE)
        targets = targets.to(DEVICE)
        optimizer.zero_grad(set_to_none=True)

        with autocast_context():
            logits = model(inputs)
            loss = criterion(logits, targets)

        scaler.scale(loss).backward()
        if max_grad_norm is not None:
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() * inputs.size(0)
        preds_all.append(torch.argmax(logits.detach(), dim=1).cpu())
        targets_all.append(targets.cpu())

    preds_np = torch.cat(preds_all).numpy()
    targets_np = torch.cat(targets_all).numpy()
    metrics = compute_classification_metrics(preds_np, targets_np)
    avg_loss = running_loss / len(loader.dataset)
    return avg_loss, metrics


def evaluate_epoch(
    model: nn.Module,
    loader: DataLoader,
    criterion: nn.Module,
    eval_window_size: Optional[int],
    eval_window_stride: Optional[int],
    aggregation: str,
) -> Tuple[float, Dict[str, float], np.ndarray, np.ndarray]:
    model.eval()
    running_loss = 0.0
    preds_all, targets_all = [], []

    with torch.no_grad():
        for inputs, targets in loader:
            inputs = inputs.to(DEVICE)
            targets = targets.to(DEVICE)
            with autocast_context():
                logits = forward_with_sliding_windows(
                    model,
                    inputs,
                    eval_window_size,
                    eval_window_stride,
                    aggregation,
                )
                loss = criterion(logits, targets)

            running_loss += loss.item() * targets.size(0)
            preds_all.append(torch.argmax(logits, dim=1).cpu())
            targets_all.append(targets.cpu())

    preds_np = torch.cat(preds_all).numpy()
    targets_np = torch.cat(targets_all).numpy()
    metrics = compute_classification_metrics(preds_np, targets_np)
    avg_loss = running_loss / len(loader.dataset)
    return avg_loss, metrics, preds_np, targets_np

# %%
def fit_model(
    config: Dict,
    train_loader: DataLoader,
    valid_loader: DataLoader,
    run_name: str,
    tensorboard: bool = True,
) -> Tuple[nn.Module, Dict[str, List[float]], Dict]:
    model = RecurrentBackbone(
        input_size=NUM_FEATURES,
        hidden_size=config['hidden_size'],
        num_layers=config['num_layers'],
        dropout=config['dropout'],
        rnn_type=config['rnn_type'],
        bidirectional=config.get('bidirectional', False),
        conv_layers=config.get('conv_layers', 0),
        conv_channels=config.get('conv_channels'),
        conv_kernel_size=config.get('conv_kernel_size', 3),
        conv_dropout=config.get('conv_dropout', 0.1),
    ).to(DEVICE)

    criterion = build_loss_fn(config).to(DEVICE)
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=config['lr'],
        weight_decay=config.get('weight_decay', 0.0),
    )
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='max',
        factor=config.get('scheduler_factor', 0.5),
        patience=config.get('scheduler_patience', 3),
    )
    scaler = create_grad_scaler()

    history: Dict[str, List[float]] = {
        'train_loss': [],
        'train_accuracy': [],
        'train_f1': [],
        'train_precision': [],
        'train_recall': [],
        'valid_loss': [],
        'valid_accuracy': [],
        'valid_f1': [],
        'valid_precision': [],
        'valid_recall': [],
        'lr': [],
    }

    run_log_dir = (LOG_DIR / run_name).resolve()
    writer = SummaryWriter(run_log_dir.as_posix()) if tensorboard else None

    best_metric = -np.inf
    best_state: Optional[Dict] = None
    patience = config.get('patience', 10)
    patience_counter = 0
    checkpoint_path = (CHECKPOINT_DIR / f'{run_name}.pt').resolve()

    eval_window_size = config.get('eval_window_size', EVAL_WINDOW_SIZE)
    eval_window_stride = config.get('eval_window_stride', EVAL_WINDOW_STRIDE)
    eval_aggregation = config.get('eval_aggregation', EVAL_AGGREGATION)

    for epoch in range(1, config['epochs'] + 1):
        train_loss, train_metrics = train_one_epoch(
            model,
            train_loader,
            criterion,
            optimizer,
            scaler,
            max_grad_norm=config.get('max_grad_norm', 5.0),
        )
        valid_loss, valid_metrics, preds, targets = evaluate_epoch(
            model,
            valid_loader,
            criterion,
            eval_window_size,
            eval_window_stride,
            eval_aggregation,
        )
        scheduler.step(valid_metrics['f1'])

        current_lr = optimizer.param_groups[0]['lr']

        history['train_loss'].append(train_loss)
        history['train_accuracy'].append(train_metrics['accuracy'])
        history['train_f1'].append(train_metrics['f1'])
        history['train_precision'].append(train_metrics['precision'])
        history['train_recall'].append(train_metrics['recall'])
        history['valid_loss'].append(valid_loss)
        history['valid_accuracy'].append(valid_metrics['accuracy'])
        history['valid_f1'].append(valid_metrics['f1'])
        history['valid_precision'].append(valid_metrics['precision'])
        history['valid_recall'].append(valid_metrics['recall'])
        history['lr'].append(current_lr)

        if writer is not None:
            writer.add_scalar('Loss/train', train_loss, epoch)
            writer.add_scalar('Loss/valid', valid_loss, epoch)
            writer.add_scalar('F1/train', train_metrics['f1'], epoch)
            writer.add_scalar('F1/valid', valid_metrics['f1'], epoch)
            writer.add_scalar('Accuracy/train', train_metrics['accuracy'], epoch)
            writer.add_scalar('Accuracy/valid', valid_metrics['accuracy'], epoch)
            writer.add_scalar('LearningRate', current_lr, epoch)

        msg = (
            f"Epoch {epoch:03d} | "
            f"train_loss={train_loss:.4f} acc={train_metrics['accuracy']:.3f} f1={train_metrics['f1']:.3f} | "
            f"valid_loss={valid_loss:.4f} acc={valid_metrics['accuracy']:.3f} f1={valid_metrics['f1']:.3f} | "
            f"lr={current_lr:.2e}"
        )
        print(msg)

        if valid_metrics['f1'] > best_metric + config.get('min_improvement', 0.0):
            best_metric = valid_metrics['f1']
            patience_counter = 0
            best_state = {
                'epoch': epoch,
                'model_state': copy.deepcopy(model.state_dict()),
                'optimizer_state': copy.deepcopy(optimizer.state_dict()),
                'metrics': valid_metrics,
                'train_metrics': train_metrics,
                'preds': preds,
                'targets': targets,
            }
            torch.save(best_state['model_state'], checkpoint_path)
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping triggered at epoch {epoch}. Best f1={best_metric:.4f}.")
                break

    if writer is not None:
        writer.close()

    if best_state is None:
        best_state = {
            'epoch': config['epochs'],
            'model_state': copy.deepcopy(model.state_dict()),
            'optimizer_state': copy.deepcopy(optimizer.state_dict()),
            'metrics': valid_metrics,
            'train_metrics': train_metrics,
            'preds': preds,
            'targets': targets,
        }
        torch.save(best_state['model_state'], checkpoint_path)

    model.load_state_dict(best_state['model_state'])
    best_state.update(
        {
            'run_name': run_name,
            'config': copy.deepcopy(config),
            'history': history,
            'checkpoint_path': checkpoint_path,
            'best_f1': best_metric,
        }
    )
    return model, history, best_state

# %%
def run_cross_validation(
    config: Dict,
    n_splits: int = 5,
    shuffle: bool = True,
    random_state: int = SEED,
) -> List[Dict]:
    skf = StratifiedKFold(n_splits=n_splits, shuffle=shuffle, random_state=random_state)
    fold_results: List[Dict] = []

    print(f"\n>>> Starting {n_splits}-fold CV for {config['run_name']} ({config['rnn_type'].upper()})")
    for fold_idx, (train_idx, valid_idx) in enumerate(skf.split(X_train_np, y_train_idx), start=1):
        fold_config = copy.deepcopy(config)
        fold_config['run_name'] = f"{config['run_name']}_fold{fold_idx}"

        X_tr, y_tr = X_train_np[train_idx], y_train_idx[train_idx]
        X_val, y_val = X_train_np[valid_idx], y_train_idx[valid_idx]

        train_loader = make_dataloader_from_arrays(
            X_tr,
            y_tr,
            batch_size=fold_config['batch_size'],
            shuffle=True,
            mode='train',
            oversample_factor=fold_config.get('oversample_factor', HIGH_PAIN_OVERSAMPLE),
            augmentation_params=fold_config.get('augmentation_params', AUGMENTATION_PARAMS),
            window_size=fold_config.get('window_size', WINDOW_SIZE),
            window_stride=fold_config.get('window_stride', WINDOW_STRIDE),
        )
        valid_loader = make_dataloader_from_arrays(
            X_val,
            y_val,
            batch_size=fold_config['batch_size'],
            shuffle=False,
            mode='valid',
            window_size=None,
            window_stride=None,
        )

        model, history, best_state = fit_model(
            fold_config,
            train_loader,
            valid_loader,
            run_name=fold_config['run_name'],
            tensorboard=fold_config.get('tensorboard', True),
        )
        best_state['fold'] = fold_idx
        best_state['model'] = model
        best_state['history'] = history
        fold_results.append(best_state)

        metrics = best_state['metrics']
        print(
            f"Fold {fold_idx}/{n_splits} | best F1={metrics['f1']:.4f} | "
            f"Accuracy={metrics['accuracy']:.4f}"
        )

    return fold_results

# %%
def summarize_cv_results(cv_results: List[Dict]) -> pd.DataFrame:
    rows = []
    for res in cv_results:
        cfg = res['config']
        metrics = res['metrics']
        rows.append({
            'run_name': res['run_name'],
            'fold': res['fold'],
            'rnn_type': cfg['rnn_type'],
            'bidirectional': cfg.get('bidirectional', False),
            'hidden_size': cfg['hidden_size'],
            'num_layers': cfg['num_layers'],
            'dropout': cfg['dropout'],
            'f1': metrics['f1'],
            'accuracy': metrics['accuracy'],
            'precision': metrics['precision'],
            'recall': metrics['recall'],
            'checkpoint': str(res['checkpoint_path']),
            'log_dir': str(LOG_DIR / res['run_name']),
        })

    df = pd.DataFrame(rows)
    agg = df.groupby(['rnn_type', 'bidirectional'])[['f1', 'accuracy', 'precision', 'recall']].agg(['mean', 'std'])
    agg.columns = ['_'.join(col) for col in agg.columns]
    agg = agg.reset_index()
    return df, agg

# %%
def prepare_config(name: str, overrides: Dict) -> Dict:
    base_config = {
        'run_name': name,
        'rnn_type': 'gru',
        'hidden_size': 128,
        'num_layers': 2,
        'dropout': 0.4,
        'bidirectional': True,
        'lr': 2e-3,
        'weight_decay': 1e-4,
        'epochs': 200,
        'batch_size': 64,
        'valid_size': 0.1,
        'patience': 20,
        'max_grad_norm': 5.0,
        'scheduler_factor': 0.5,
        'scheduler_patience': 5,
        'min_improvement': 5e-4,
        'tensorboard': True,
        'oversample_factor': HIGH_PAIN_OVERSAMPLE,
        'window_size': WINDOW_SIZE,
        'window_stride': WINDOW_STRIDE,
        'eval_window_size': EVAL_WINDOW_SIZE,
        'eval_window_stride': EVAL_WINDOW_STRIDE,
        'eval_aggregation': EVAL_AGGREGATION,
        'loss_type': 'focal',
        'use_class_weights': True,
        'focal_gamma': 0.75,
        'augmentation_params': AUGMENTATION_PARAMS,
        'conv_layers': 2,
        'conv_channels': min(NUM_FEATURES, 128),
        'conv_kernel_size': 5,
        'conv_dropout': 0.1,
    }
    config = copy.deepcopy(base_config)
    config.update(overrides)
    return config


def run_experiment(config: Dict) -> Dict:
    run_name = config.get('run_name') or f"{config['rnn_type'].upper()}_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
    config = copy.deepcopy(config)
    config['run_name'] = run_name

    train_loader, valid_loader, (X_tr, y_tr, X_val, y_val) = create_dataloaders(
        X_train_np,
        y_train_idx,
        valid_size=config.get('valid_size', 0.2),
        batch_size=config['batch_size'],
        oversample_factor=config.get('oversample_factor', HIGH_PAIN_OVERSAMPLE),
        window_size=config.get('window_size', WINDOW_SIZE),
        window_stride=config.get('window_stride', WINDOW_STRIDE),
        augmentation_params=config.get('augmentation_params', AUGMENTATION_PARAMS),
    )

    model, history, best_state = fit_model(
        config,
        train_loader,
        valid_loader,
        run_name=run_name,
        tensorboard=config.get('tensorboard', True),
    )

    best_state['data_split'] = {
        'X_train': X_tr,
        'y_train': y_tr,
        'X_valid': X_val,
        'y_valid': y_val,
    }
    best_state['model'] = model
    best_state['history'] = history
    return best_state

# %%
EXPERIMENT_CONFIGS = [

    prepare_config('GRU_BI', {'rnn_type': 'gru', 'bidirectional': True}),
    prepare_config('GRU_SINGLE', {'rnn_type': 'gru', 'bidirectional': False}),

]

experiment_results: List[Dict] = []
for cfg in EXPERIMENT_CONFIGS:
    print(f"\n=== Running experiment: {cfg['run_name']} ({cfg['rnn_type'].upper()} - {'BI' if cfg['bidirectional'] else 'UNI'}) ===")
    result = run_experiment(cfg)
    experiment_results.append(result)
    print(
        f"Best validation F1: {result['best_f1']:.4f} at epoch {result['epoch']} | "
        f"Accuracy: {result['metrics']['accuracy']:.4f}"
    )

BEST_FOR_CV = prepare_config('GRU_BI', {'bidirectional': True})
cv_results = run_cross_validation(BEST_FOR_CV, n_splits=5)
# Out:
# === Running experiment: GRU_BI (GRU - BI) ===
# Epoch 001 | train_loss=0.2583 acc=0.700 f1=0.307 | valid_loss=0.2046 acc=0.791 f1=0.357 | lr=2.00e-03
# Epoch 002 | train_loss=0.2019 acc=0.761 f1=0.499 | valid_loss=0.1701 acc=0.761 f1=0.353 | lr=2.00e-03
# Epoch 003 | train_loss=0.1809 acc=0.798 f1=0.621 | valid_loss=0.1918 acc=0.731 f1=0.373 | lr=2.00e-03
# Epoch 004 | train_loss=0.1607 acc=0.807 f1=0.654 | valid_loss=0.1695 acc=0.806 f1=0.514 | lr=2.00e-03
# Epoch 005 | train_loss=0.1515 acc=0.831 f1=0.722 | valid_loss=0.1339 acc=0.851 f1=0.605 | lr=2.00e-03
# Epoch 006 | train_loss=0.1334 acc=0.835 f1=0.715 | valid_loss=0.1171 acc=0.821 f1=0.579 | lr=2.00e-03
# Epoch 007 | train_loss=0.1333 acc=0.849 f1=0.731 | valid_loss=0.1630 acc=0.851 f1=0.626 | lr=2.00e-03
# Epoch 008 | train_loss=0.1248 acc=0.866 f1=0.777 | valid_loss=0.1569 acc=0.836 f1=0.618 | lr=2.00e-03
# Epoch 009 | train_loss=0.0939 acc=0.879 f1=0.810 | valid_loss=0.1422 acc=0.821 f1=0.611 | lr=2.00e-03
# Epoch 010 | train_loss=0.1132 acc=0.870 f1=0.807 | valid_loss=0.1093 acc=0.851 f1=0.666 | lr=2.00e-03
# Epoch 011 | train_loss=0.0953 acc=0.894 f1=0.842 | valid_loss=0.1097 acc=0.896 f1=0.761 | lr=2.00e-03
# Epoch 012 | train_loss=0.0934 acc=0.894 f1=0.838 | valid_loss=0.1611 acc=0.821 f1=0.587 | lr=2.00e-03
# Epoch 013 | train_loss=0.1031 acc=0.891 f1=0.826 | valid_loss=0.1174 acc=0.851 f1=0.671 | lr=2.00e-03
# Epoch 014 | train_loss=0.0970 acc=0.874 f1=0.802 | valid_loss=0.0896 acc=0.896 f1=0.710 | lr=2.00e-03
# Epoch 015 | train_loss=0.0907 acc=0.888 f1=0.812 | valid_loss=0.1302 acc=0.761 f1=0.595 | lr=2.00e-03
# Epoch 016 | train_loss=0.1274 acc=0.828 f1=0.751 | valid_loss=0.0937 acc=0.866 f1=0.666 | lr=2.00e-03
# Epoch 017 | train_loss=0.1061 acc=0.871 f1=0.788 | valid_loss=0.1215 acc=0.806 f1=0.592 | lr=1.00e-03
# Epoch 018 | train_loss=0.0935 acc=0.888 f1=0.835 | valid_loss=0.1099 acc=0.851 f1=0.608 | lr=1.00e-03
# Epoch 019 | train_loss=0.0868 acc=0.902 f1=0.852 | valid_loss=0.1416 acc=0.836 f1=0.594 | lr=1.00e-03
# Epoch 020 | train_loss=0.0919 acc=0.862 f1=0.809 | valid_loss=0.1286 acc=0.866 f1=0.644 | lr=1.00e-03
# Epoch 021 | train_loss=0.0870 acc=0.896 f1=0.834 | valid_loss=0.0976 acc=0.925 f1=0.788 | lr=1.00e-03
# Epoch 022 | train_loss=0.0725 acc=0.918 f1=0.874 | valid_loss=0.1146 acc=0.896 f1=0.716 | lr=1.00e-03
# Epoch 023 | train_loss=0.0575 acc=0.935 f1=0.902 | valid_loss=0.1122 acc=0.896 f1=0.716 | lr=1.00e-03
# Epoch 024 | train_loss=0.0648 acc=0.918 f1=0.870 | valid_loss=0.0920 acc=0.896 f1=0.751 | lr=1.00e-03
# Epoch 025 | train_loss=0.0637 acc=0.924 f1=0.884 | valid_loss=0.1144 acc=0.866 f1=0.662 | lr=1.00e-03
# Epoch 026 | train_loss=0.0667 acc=0.898 f1=0.857 | valid_loss=0.1041 acc=0.806 f1=0.643 | lr=1.00e-03
# Epoch 027 | train_loss=0.0610 acc=0.924 f1=0.886 | valid_loss=0.0731 acc=0.910 f1=0.768 | lr=5.00e-04
# Epoch 028 | train_loss=0.0567 acc=0.919 f1=0.876 | valid_loss=0.0728 acc=0.910 f1=0.784 | lr=5.00e-04
# Epoch 029 | train_loss=0.0610 acc=0.930 f1=0.903 | valid_loss=0.0754 acc=0.925 f1=0.806 | lr=5.00e-04
# Epoch 030 | train_loss=0.0543 acc=0.943 f1=0.911 | valid_loss=0.0889 acc=0.910 f1=0.757 | lr=5.00e-04
# Epoch 031 | train_loss=0.0586 acc=0.935 f1=0.903 | valid_loss=0.0840 acc=0.925 f1=0.798 | lr=5.00e-04
# Epoch 032 | train_loss=0.0545 acc=0.941 f1=0.904 | valid_loss=0.0784 acc=0.940 f1=0.843 | lr=5.00e-04
# Epoch 033 | train_loss=0.0560 acc=0.925 f1=0.897 | valid_loss=0.0998 acc=0.851 f1=0.744 | lr=5.00e-04
# Epoch 034 | train_loss=0.0584 acc=0.919 f1=0.888 | valid_loss=0.0768 acc=0.925 f1=0.824 | lr=5.00e-04
# Epoch 035 | train_loss=0.0473 acc=0.944 f1=0.917 | valid_loss=0.0701 acc=0.925 f1=0.859 | lr=5.00e-04
# Epoch 036 | train_loss=0.0510 acc=0.944 f1=0.920 | valid_loss=0.0706 acc=0.940 f1=0.871 | lr=5.00e-04
# Epoch 037 | train_loss=0.0510 acc=0.941 f1=0.913 | valid_loss=0.0753 acc=0.940 f1=0.843 | lr=5.00e-04
# Epoch 038 | train_loss=0.0413 acc=0.935 f1=0.909 | valid_loss=0.0879 acc=0.925 f1=0.824 | lr=5.00e-04
# Epoch 039 | train_loss=0.0474 acc=0.944 f1=0.918 | valid_loss=0.0676 acc=0.910 f1=0.807 | lr=5.00e-04
# Epoch 040 | train_loss=0.0386 acc=0.949 f1=0.924 | valid_loss=0.0650 acc=0.896 f1=0.788 | lr=5.00e-04
# Epoch 041 | train_loss=0.0452 acc=0.946 f1=0.922 | valid_loss=0.0562 acc=0.925 f1=0.869 | lr=5.00e-04
# Epoch 042 | train_loss=0.0483 acc=0.946 f1=0.919 | valid_loss=0.0614 acc=0.940 f1=0.860 | lr=2.50e-04
# Epoch 043 | train_loss=0.0395 acc=0.947 f1=0.924 | valid_loss=0.0600 acc=0.910 f1=0.822 | lr=2.50e-04
# Epoch 044 | train_loss=0.0407 acc=0.939 f1=0.914 | valid_loss=0.0540 acc=0.925 f1=0.847 | lr=2.50e-04
# Epoch 045 | train_loss=0.0436 acc=0.939 f1=0.913 | valid_loss=0.0538 acc=0.910 f1=0.825 | lr=2.50e-04
# Epoch 046 | train_loss=0.0365 acc=0.949 f1=0.931 | valid_loss=0.0692 acc=0.881 f1=0.794 | lr=2.50e-04
# Epoch 047 | train_loss=0.0463 acc=0.929 f1=0.898 | valid_loss=0.0678 acc=0.925 f1=0.829 | lr=2.50e-04
# Epoch 048 | train_loss=0.0504 acc=0.938 f1=0.908 | valid_loss=0.0713 acc=0.940 f1=0.871 | lr=1.25e-04
# Epoch 049 | train_loss=0.0519 acc=0.929 f1=0.889 | valid_loss=0.0759 acc=0.910 f1=0.769 | lr=1.25e-04
# Epoch 050 | train_loss=0.0392 acc=0.946 f1=0.920 | valid_loss=0.0691 acc=0.925 f1=0.823 | lr=1.25e-04
# Epoch 051 | train_loss=0.0370 acc=0.947 f1=0.927 | valid_loss=0.0675 acc=0.940 f1=0.890 | lr=1.25e-04
# Epoch 052 | train_loss=0.0384 acc=0.947 f1=0.920 | valid_loss=0.0659 acc=0.940 f1=0.871 | lr=1.25e-04
# Epoch 053 | train_loss=0.0341 acc=0.963 f1=0.947 | valid_loss=0.0660 acc=0.940 f1=0.871 | lr=1.25e-04
# Epoch 054 | train_loss=0.0357 acc=0.955 f1=0.936 | valid_loss=0.0670 acc=0.910 f1=0.807 | lr=1.25e-04
# Epoch 055 | train_loss=0.0378 acc=0.953 f1=0.933 | valid_loss=0.0730 acc=0.940 f1=0.871 | lr=1.25e-04
# Epoch 056 | train_loss=0.0376 acc=0.949 f1=0.924 | valid_loss=0.0652 acc=0.940 f1=0.871 | lr=1.25e-04
# Epoch 057 | train_loss=0.0379 acc=0.949 f1=0.928 | valid_loss=0.0656 acc=0.925 f1=0.847 | lr=6.25e-05
# Epoch 058 | train_loss=0.0398 acc=0.947 f1=0.925 | valid_loss=0.0770 acc=0.940 f1=0.871 | lr=6.25e-05
# Epoch 059 | train_loss=0.0337 acc=0.955 f1=0.936 | valid_loss=0.0668 acc=0.940 f1=0.871 | lr=6.25e-05
# Epoch 060 | train_loss=0.0310 acc=0.966 f1=0.950 | valid_loss=0.0644 acc=0.940 f1=0.871 | lr=6.25e-05
# Epoch 061 | train_loss=0.0357 acc=0.953 f1=0.933 | valid_loss=0.0733 acc=0.940 f1=0.871 | lr=6.25e-05
# Epoch 062 | train_loss=0.0377 acc=0.944 f1=0.918 | valid_loss=0.0760 acc=0.925 f1=0.847 | lr=6.25e-05
# Epoch 063 | train_loss=0.0375 acc=0.950 f1=0.931 | valid_loss=0.0641 acc=0.925 f1=0.847 | lr=3.13e-05
# Epoch 064 | train_loss=0.0438 acc=0.941 f1=0.917 | valid_loss=0.0602 acc=0.940 f1=0.871 | lr=3.13e-05
# Epoch 065 | train_loss=0.0368 acc=0.955 f1=0.940 | valid_loss=0.0583 acc=0.925 f1=0.847 | lr=3.13e-05
# Epoch 066 | train_loss=0.0275 acc=0.957 f1=0.938 | valid_loss=0.0622 acc=0.925 f1=0.847 | lr=3.13e-05
# Epoch 067 | train_loss=0.0440 acc=0.946 f1=0.924 | valid_loss=0.0678 acc=0.910 f1=0.825 | lr=3.13e-05
# Epoch 068 | train_loss=0.0342 acc=0.952 f1=0.934 | valid_loss=0.0683 acc=0.910 f1=0.825 | lr=3.13e-05
# Epoch 069 | train_loss=0.0433 acc=0.943 f1=0.916 | valid_loss=0.0671 acc=0.910 f1=0.825 | lr=1.56e-05
# Epoch 070 | train_loss=0.0296 acc=0.953 f1=0.935 | valid_loss=0.0623 acc=0.940 f1=0.871 | lr=1.56e-05
# Epoch 071 | train_loss=0.0413 acc=0.935 f1=0.908 | valid_loss=0.0632 acc=0.940 f1=0.871 | lr=1.56e-05
# Early stopping triggered at epoch 71. Best f1=0.8898.
# Best validation F1: 0.8898 at epoch 51 | Accuracy: 0.9403
#
# === Running experiment: GRU_SINGLE (GRU - UNI) ===
# Epoch 001 | train_loss=0.2605 acc=0.671 f1=0.318 | valid_loss=0.2210 acc=0.806 f1=0.435 | lr=2.00e-03
# Epoch 002 | train_loss=0.2166 acc=0.738 f1=0.443 | valid_loss=0.1753 acc=0.776 f1=0.400 | lr=2.00e-03
# Epoch 003 | train_loss=0.1964 acc=0.748 f1=0.479 | valid_loss=0.1611 acc=0.791 f1=0.368 | lr=2.00e-03
# Epoch 004 | train_loss=0.1805 acc=0.769 f1=0.501 | valid_loss=0.1684 acc=0.791 f1=0.373 | lr=2.00e-03
# Epoch 005 | train_loss=0.1624 acc=0.828 f1=0.693 | valid_loss=0.1683 acc=0.761 f1=0.446 | lr=2.00e-03
# Epoch 006 | train_loss=0.1483 acc=0.832 f1=0.728 | valid_loss=0.1652 acc=0.776 f1=0.456 | lr=2.00e-03
# Epoch 007 | train_loss=0.1569 acc=0.823 f1=0.690 | valid_loss=0.1776 acc=0.791 f1=0.538 | lr=2.00e-03
# Epoch 008 | train_loss=0.1323 acc=0.857 f1=0.762 | valid_loss=0.1361 acc=0.851 f1=0.632 | lr=2.00e-03
# Epoch 009 | train_loss=0.1158 acc=0.871 f1=0.781 | valid_loss=0.1638 acc=0.821 f1=0.678 | lr=2.00e-03
# Epoch 010 | train_loss=0.1179 acc=0.854 f1=0.771 | valid_loss=0.1050 acc=0.851 f1=0.693 | lr=2.00e-03
# Epoch 011 | train_loss=0.1259 acc=0.865 f1=0.777 | valid_loss=0.1274 acc=0.896 f1=0.754 | lr=2.00e-03
# Epoch 012 | train_loss=0.1064 acc=0.874 f1=0.782 | valid_loss=0.1538 acc=0.821 f1=0.594 | lr=2.00e-03
# Epoch 013 | train_loss=0.0960 acc=0.880 f1=0.815 | valid_loss=0.1760 acc=0.821 f1=0.618 | lr=2.00e-03
# Epoch 014 | train_loss=0.0907 acc=0.891 f1=0.828 | valid_loss=0.1349 acc=0.821 f1=0.587 | lr=2.00e-03
# Epoch 015 | train_loss=0.0719 acc=0.911 f1=0.854 | valid_loss=0.1506 acc=0.791 f1=0.632 | lr=2.00e-03
# Epoch 016 | train_loss=0.0798 acc=0.884 f1=0.825 | valid_loss=0.1109 acc=0.851 f1=0.680 | lr=2.00e-03
# Epoch 017 | train_loss=0.1027 acc=0.876 f1=0.793 | valid_loss=0.1661 acc=0.776 f1=0.510 | lr=1.00e-03
# Epoch 018 | train_loss=0.0942 acc=0.871 f1=0.786 | valid_loss=0.1340 acc=0.806 f1=0.581 | lr=1.00e-03
# Epoch 019 | train_loss=0.0764 acc=0.898 f1=0.859 | valid_loss=0.1350 acc=0.836 f1=0.673 | lr=1.00e-03
# Epoch 020 | train_loss=0.0829 acc=0.908 f1=0.859 | valid_loss=0.0959 acc=0.881 f1=0.722 | lr=1.00e-03
# Epoch 021 | train_loss=0.0748 acc=0.904 f1=0.855 | valid_loss=0.1031 acc=0.836 f1=0.635 | lr=1.00e-03
# Epoch 022 | train_loss=0.0689 acc=0.915 f1=0.869 | valid_loss=0.0926 acc=0.866 f1=0.672 | lr=1.00e-03
# Epoch 023 | train_loss=0.0687 acc=0.924 f1=0.879 | valid_loss=0.1089 acc=0.881 f1=0.739 | lr=5.00e-04
# Epoch 024 | train_loss=0.0650 acc=0.927 f1=0.891 | valid_loss=0.0987 acc=0.881 f1=0.721 | lr=5.00e-04
# Epoch 025 | train_loss=0.0501 acc=0.936 f1=0.910 | valid_loss=0.1048 acc=0.851 f1=0.702 | lr=5.00e-04
# Epoch 026 | train_loss=0.0621 acc=0.924 f1=0.883 | valid_loss=0.0983 acc=0.851 f1=0.689 | lr=5.00e-04
# Epoch 027 | train_loss=0.0657 acc=0.924 f1=0.880 | valid_loss=0.0996 acc=0.866 f1=0.707 | lr=5.00e-04
# Epoch 028 | train_loss=0.0559 acc=0.932 f1=0.897 | valid_loss=0.1041 acc=0.851 f1=0.720 | lr=5.00e-04
# Epoch 029 | train_loss=0.0591 acc=0.935 f1=0.904 | valid_loss=0.0847 acc=0.896 f1=0.785 | lr=5.00e-04
# Epoch 030 | train_loss=0.0508 acc=0.935 f1=0.909 | valid_loss=0.0890 acc=0.866 f1=0.735 | lr=5.00e-04
# Epoch 031 | train_loss=0.0555 acc=0.941 f1=0.911 | valid_loss=0.0780 acc=0.851 f1=0.688 | lr=5.00e-04
# Epoch 032 | train_loss=0.0542 acc=0.925 f1=0.893 | valid_loss=0.0772 acc=0.851 f1=0.710 | lr=5.00e-04
# Epoch 033 | train_loss=0.0555 acc=0.930 f1=0.895 | valid_loss=0.0708 acc=0.881 f1=0.761 | lr=5.00e-04
# Epoch 034 | train_loss=0.0511 acc=0.935 f1=0.904 | valid_loss=0.0859 acc=0.866 f1=0.744 | lr=5.00e-04
# Epoch 035 | train_loss=0.0453 acc=0.944 f1=0.917 | valid_loss=0.0842 acc=0.881 f1=0.745 | lr=2.50e-04
# Epoch 036 | train_loss=0.0361 acc=0.957 f1=0.937 | valid_loss=0.0934 acc=0.851 f1=0.710 | lr=2.50e-04
# Epoch 037 | train_loss=0.0475 acc=0.938 f1=0.909 | valid_loss=0.0888 acc=0.896 f1=0.761 | lr=2.50e-04
# Epoch 038 | train_loss=0.0516 acc=0.946 f1=0.921 | valid_loss=0.0921 acc=0.881 f1=0.770 | lr=2.50e-04
# Epoch 039 | train_loss=0.0400 acc=0.935 f1=0.911 | valid_loss=0.0906 acc=0.881 f1=0.761 | lr=2.50e-04
# Epoch 040 | train_loss=0.0423 acc=0.946 f1=0.927 | valid_loss=0.1078 acc=0.836 f1=0.696 | lr=2.50e-04
# Epoch 041 | train_loss=0.0517 acc=0.933 f1=0.907 | valid_loss=0.1011 acc=0.866 f1=0.755 | lr=1.25e-04
# Epoch 042 | train_loss=0.0488 acc=0.938 f1=0.912 | valid_loss=0.0874 acc=0.896 f1=0.771 | lr=1.25e-04
# Epoch 043 | train_loss=0.0393 acc=0.952 f1=0.935 | valid_loss=0.0835 acc=0.881 f1=0.745 | lr=1.25e-04
# Epoch 044 | train_loss=0.0391 acc=0.950 f1=0.929 | valid_loss=0.0859 acc=0.925 f1=0.815 | lr=1.25e-04
# Epoch 045 | train_loss=0.0579 acc=0.930 f1=0.891 | valid_loss=0.0957 acc=0.925 f1=0.824 | lr=1.25e-04
# Epoch 046 | train_loss=0.0463 acc=0.946 f1=0.920 | valid_loss=0.0851 acc=0.896 f1=0.788 | lr=1.25e-04
# Epoch 047 | train_loss=0.0438 acc=0.947 f1=0.923 | valid_loss=0.0798 acc=0.910 f1=0.807 | lr=1.25e-04
# Epoch 048 | train_loss=0.0319 acc=0.961 f1=0.947 | valid_loss=0.0727 acc=0.896 f1=0.781 | lr=1.25e-04
# Epoch 049 | train_loss=0.0400 acc=0.944 f1=0.921 | valid_loss=0.0837 acc=0.910 f1=0.807 | lr=1.25e-04
# Epoch 050 | train_loss=0.0393 acc=0.950 f1=0.929 | valid_loss=0.0844 acc=0.910 f1=0.807 | lr=1.25e-04
# Epoch 051 | train_loss=0.0494 acc=0.933 f1=0.905 | valid_loss=0.0831 acc=0.910 f1=0.807 | lr=6.25e-05
# Epoch 052 | train_loss=0.0450 acc=0.955 f1=0.934 | valid_loss=0.0776 acc=0.896 f1=0.761 | lr=6.25e-05
# Epoch 053 | train_loss=0.0388 acc=0.949 f1=0.927 | valid_loss=0.0790 acc=0.881 f1=0.772 | lr=6.25e-05
# Epoch 054 | train_loss=0.0383 acc=0.946 f1=0.923 | valid_loss=0.0840 acc=0.881 f1=0.770 | lr=6.25e-05
# Epoch 055 | train_loss=0.0371 acc=0.949 f1=0.926 | valid_loss=0.0767 acc=0.866 f1=0.744 | lr=6.25e-05
# Epoch 056 | train_loss=0.0451 acc=0.947 f1=0.923 | valid_loss=0.0784 acc=0.881 f1=0.770 | lr=6.25e-05
# Epoch 057 | train_loss=0.0436 acc=0.935 f1=0.912 | valid_loss=0.0691 acc=0.896 f1=0.781 | lr=3.13e-05
# Epoch 058 | train_loss=0.0383 acc=0.947 f1=0.927 | valid_loss=0.0692 acc=0.910 f1=0.807 | lr=3.13e-05
# Epoch 059 | train_loss=0.0310 acc=0.950 f1=0.927 | valid_loss=0.0766 acc=0.881 f1=0.770 | lr=3.13e-05
# Epoch 060 | train_loss=0.0391 acc=0.944 f1=0.927 | valid_loss=0.0826 acc=0.881 f1=0.770 | lr=3.13e-05
# Epoch 061 | train_loss=0.0433 acc=0.946 f1=0.917 | valid_loss=0.0916 acc=0.881 f1=0.770 | lr=3.13e-05
# Epoch 062 | train_loss=0.0472 acc=0.947 f1=0.927 | valid_loss=0.0834 acc=0.910 f1=0.796 | lr=3.13e-05
# Epoch 063 | train_loss=0.0467 acc=0.944 f1=0.922 | valid_loss=0.0875 acc=0.866 f1=0.755 | lr=1.56e-05
# Epoch 064 | train_loss=0.0390 acc=0.953 f1=0.934 | valid_loss=0.0849 acc=0.881 f1=0.770 | lr=1.56e-05
# Epoch 065 | train_loss=0.0428 acc=0.950 f1=0.930 | valid_loss=0.0743 acc=0.910 f1=0.807 | lr=1.56e-05
# Early stopping triggered at epoch 65. Best f1=0.8235.
# Best validation F1: 0.8235 at epoch 45 | Accuracy: 0.9254
#
# >>> Starting 5-fold CV for GRU_BI (GRU)
# Epoch 001 | train_loss=0.2584 acc=0.689 f1=0.337 | valid_loss=0.2003 acc=0.805 f1=0.458 | lr=2.00e-03
# Epoch 002 | train_loss=0.2033 acc=0.741 f1=0.474 | valid_loss=0.1470 acc=0.797 f1=0.469 | lr=2.00e-03
# Epoch 003 | train_loss=0.1709 acc=0.769 f1=0.571 | valid_loss=0.1288 acc=0.835 f1=0.655 | lr=2.00e-03
# Epoch 004 | train_loss=0.1581 acc=0.799 f1=0.657 | valid_loss=0.1129 acc=0.880 f1=0.737 | lr=2.00e-03
# Epoch 005 | train_loss=0.1246 acc=0.839 f1=0.723 | valid_loss=0.1004 acc=0.887 f1=0.773 | lr=2.00e-03
# Epoch 006 | train_loss=0.1265 acc=0.848 f1=0.746 | valid_loss=0.1007 acc=0.857 f1=0.733 | lr=2.00e-03
# Epoch 007 | train_loss=0.1026 acc=0.881 f1=0.792 | valid_loss=0.0705 acc=0.902 f1=0.766 | lr=2.00e-03
# Epoch 008 | train_loss=0.1191 acc=0.857 f1=0.768 | valid_loss=0.1056 acc=0.865 f1=0.728 | lr=2.00e-03
# Epoch 009 | train_loss=0.1076 acc=0.864 f1=0.771 | valid_loss=0.0724 acc=0.917 f1=0.803 | lr=2.00e-03
# Epoch 010 | train_loss=0.0867 acc=0.892 f1=0.818 | valid_loss=0.0850 acc=0.872 f1=0.769 | lr=2.00e-03
# Epoch 011 | train_loss=0.0886 acc=0.893 f1=0.831 | valid_loss=0.0633 acc=0.925 f1=0.846 | lr=2.00e-03
# Epoch 012 | train_loss=0.0992 acc=0.881 f1=0.809 | valid_loss=0.0788 acc=0.887 f1=0.801 | lr=2.00e-03
# Epoch 013 | train_loss=0.0876 acc=0.902 f1=0.845 | valid_loss=0.0485 acc=0.940 f1=0.887 | lr=2.00e-03
# Epoch 014 | train_loss=0.0769 acc=0.911 f1=0.859 | valid_loss=0.0581 acc=0.925 f1=0.846 | lr=2.00e-03
# Epoch 015 | train_loss=0.0712 acc=0.914 f1=0.861 | valid_loss=0.0480 acc=0.917 f1=0.816 | lr=2.00e-03
# Epoch 016 | train_loss=0.0670 acc=0.930 f1=0.895 | valid_loss=0.0470 acc=0.925 f1=0.848 | lr=2.00e-03
# Epoch 017 | train_loss=0.0563 acc=0.920 f1=0.877 | valid_loss=0.0423 acc=0.925 f1=0.845 | lr=2.00e-03
# Epoch 018 | train_loss=0.0630 acc=0.909 f1=0.853 | valid_loss=0.0543 acc=0.932 f1=0.874 | lr=2.00e-03
# Epoch 019 | train_loss=0.0621 acc=0.927 f1=0.880 | valid_loss=0.0594 acc=0.902 f1=0.787 | lr=1.00e-03
# Epoch 020 | train_loss=0.0657 acc=0.920 f1=0.868 | valid_loss=0.0491 acc=0.917 f1=0.814 | lr=1.00e-03
# Epoch 021 | train_loss=0.0513 acc=0.930 f1=0.889 | valid_loss=0.0491 acc=0.940 f1=0.878 | lr=1.00e-03
# Epoch 022 | train_loss=0.0549 acc=0.934 f1=0.896 | valid_loss=0.0440 acc=0.925 f1=0.824 | lr=1.00e-03
# Epoch 023 | train_loss=0.0446 acc=0.930 f1=0.896 | valid_loss=0.0372 acc=0.940 f1=0.878 | lr=1.00e-03
# Epoch 024 | train_loss=0.0426 acc=0.937 f1=0.909 | valid_loss=0.0347 acc=0.947 f1=0.901 | lr=1.00e-03
# Epoch 025 | train_loss=0.0304 acc=0.953 f1=0.933 | valid_loss=0.0350 acc=0.947 f1=0.901 | lr=1.00e-03
# Epoch 026 | train_loss=0.0384 acc=0.939 f1=0.908 | valid_loss=0.0284 acc=0.947 f1=0.889 | lr=1.00e-03
# Epoch 027 | train_loss=0.0455 acc=0.941 f1=0.920 | valid_loss=0.0291 acc=0.947 f1=0.901 | lr=1.00e-03
# Epoch 028 | train_loss=0.0365 acc=0.944 f1=0.922 | valid_loss=0.0277 acc=0.947 f1=0.902 | lr=1.00e-03
# Epoch 029 | train_loss=0.0331 acc=0.960 f1=0.941 | valid_loss=0.0292 acc=0.955 f1=0.912 | lr=1.00e-03
# Epoch 030 | train_loss=0.0431 acc=0.935 f1=0.909 | valid_loss=0.0296 acc=0.955 f1=0.912 | lr=1.00e-03
# Epoch 031 | train_loss=0.0356 acc=0.942 f1=0.921 | valid_loss=0.0410 acc=0.940 f1=0.883 | lr=1.00e-03
# Epoch 032 | train_loss=0.0343 acc=0.953 f1=0.932 | valid_loss=0.0391 acc=0.925 f1=0.843 | lr=1.00e-03
# Epoch 033 | train_loss=0.0308 acc=0.956 f1=0.936 | valid_loss=0.0390 acc=0.940 f1=0.883 | lr=1.00e-03
# Epoch 034 | train_loss=0.0414 acc=0.948 f1=0.924 | valid_loss=0.0336 acc=0.947 f1=0.897 | lr=1.00e-03
# Epoch 035 | train_loss=0.0389 acc=0.949 f1=0.923 | valid_loss=0.0323 acc=0.947 f1=0.911 | lr=5.00e-04
# Epoch 036 | train_loss=0.0302 acc=0.958 f1=0.941 | valid_loss=0.0264 acc=0.970 f1=0.947 | lr=5.00e-04
# Epoch 037 | train_loss=0.0265 acc=0.962 f1=0.945 | valid_loss=0.0250 acc=0.955 f1=0.915 | lr=5.00e-04
# Epoch 038 | train_loss=0.0297 acc=0.955 f1=0.936 | valid_loss=0.0236 acc=0.962 f1=0.924 | lr=5.00e-04
# Epoch 039 | train_loss=0.0257 acc=0.958 f1=0.942 | valid_loss=0.0238 acc=0.947 f1=0.900 | lr=5.00e-04
# Epoch 040 | train_loss=0.0251 acc=0.969 f1=0.955 | valid_loss=0.0206 acc=0.962 f1=0.924 | lr=5.00e-04
# Epoch 041 | train_loss=0.0249 acc=0.967 f1=0.951 | valid_loss=0.0230 acc=0.962 f1=0.923 | lr=5.00e-04
# Epoch 042 | train_loss=0.0221 acc=0.970 f1=0.960 | valid_loss=0.0234 acc=0.970 f1=0.935 | lr=2.50e-04
# Epoch 043 | train_loss=0.0272 acc=0.963 f1=0.943 | valid_loss=0.0200 acc=0.977 f1=0.958 | lr=2.50e-04
# Epoch 044 | train_loss=0.0274 acc=0.963 f1=0.943 | valid_loss=0.0199 acc=0.970 f1=0.938 | lr=2.50e-04
# Epoch 045 | train_loss=0.0258 acc=0.965 f1=0.949 | valid_loss=0.0196 acc=0.970 f1=0.946 | lr=2.50e-04
# Epoch 046 | train_loss=0.0224 acc=0.969 f1=0.956 | valid_loss=0.0192 acc=0.992 f1=0.985 | lr=2.50e-04
# Epoch 047 | train_loss=0.0292 acc=0.955 f1=0.932 | valid_loss=0.0204 acc=0.985 f1=0.962 | lr=2.50e-04
# Epoch 048 | train_loss=0.0218 acc=0.969 f1=0.957 | valid_loss=0.0213 acc=0.985 f1=0.962 | lr=2.50e-04
# Epoch 049 | train_loss=0.0223 acc=0.972 f1=0.959 | valid_loss=0.0213 acc=0.970 f1=0.935 | lr=2.50e-04
# Epoch 050 | train_loss=0.0239 acc=0.970 f1=0.957 | valid_loss=0.0239 acc=0.955 f1=0.912 | lr=2.50e-04
# Epoch 051 | train_loss=0.0187 acc=0.977 f1=0.967 | valid_loss=0.0218 acc=0.962 f1=0.924 | lr=2.50e-04
# Epoch 052 | train_loss=0.0249 acc=0.969 f1=0.953 | valid_loss=0.0194 acc=0.947 f1=0.900 | lr=1.25e-04
# Epoch 053 | train_loss=0.0188 acc=0.972 f1=0.961 | valid_loss=0.0190 acc=0.962 f1=0.935 | lr=1.25e-04
# Epoch 054 | train_loss=0.0215 acc=0.972 f1=0.957 | valid_loss=0.0201 acc=0.962 f1=0.924 | lr=1.25e-04
# Epoch 055 | train_loss=0.0160 acc=0.977 f1=0.969 | valid_loss=0.0199 acc=0.970 f1=0.935 | lr=1.25e-04
# Epoch 056 | train_loss=0.0256 acc=0.965 f1=0.952 | valid_loss=0.0203 acc=0.970 f1=0.935 | lr=1.25e-04
# Epoch 057 | train_loss=0.0227 acc=0.962 f1=0.949 | valid_loss=0.0214 acc=0.962 f1=0.923 | lr=1.25e-04
# Epoch 058 | train_loss=0.0226 acc=0.967 f1=0.955 | valid_loss=0.0226 acc=0.962 f1=0.923 | lr=6.25e-05
# Epoch 059 | train_loss=0.0158 acc=0.979 f1=0.971 | valid_loss=0.0224 acc=0.962 f1=0.923 | lr=6.25e-05
# Epoch 060 | train_loss=0.0140 acc=0.981 f1=0.974 | valid_loss=0.0219 acc=0.962 f1=0.923 | lr=6.25e-05
# Epoch 061 | train_loss=0.0202 acc=0.972 f1=0.960 | valid_loss=0.0219 acc=0.962 f1=0.923 | lr=6.25e-05
# Epoch 062 | train_loss=0.0218 acc=0.976 f1=0.964 | valid_loss=0.0213 acc=0.970 f1=0.935 | lr=6.25e-05
# Epoch 063 | train_loss=0.0147 acc=0.977 f1=0.968 | valid_loss=0.0205 acc=0.970 f1=0.935 | lr=6.25e-05
# Epoch 064 | train_loss=0.0230 acc=0.979 f1=0.969 | valid_loss=0.0209 acc=0.970 f1=0.935 | lr=3.13e-05
# Epoch 065 | train_loss=0.0189 acc=0.976 f1=0.963 | valid_loss=0.0209 acc=0.970 f1=0.935 | lr=3.13e-05
# Epoch 066 | train_loss=0.0253 acc=0.963 f1=0.944 | valid_loss=0.0199 acc=0.970 f1=0.935 | lr=3.13e-05
# Early stopping triggered at epoch 66. Best f1=0.9850.
# Fold 1/5 | best F1=0.9850 | Accuracy=0.9925
# Epoch 001 | train_loss=0.2672 acc=0.672 f1=0.336 | valid_loss=0.2272 acc=0.780 f1=0.396 | lr=2.00e-03
# Epoch 002 | train_loss=0.2107 acc=0.754 f1=0.467 | valid_loss=0.1657 acc=0.780 f1=0.371 | lr=2.00e-03
# Epoch 003 | train_loss=0.1711 acc=0.794 f1=0.604 | valid_loss=0.1390 acc=0.864 f1=0.699 | lr=2.00e-03
# Epoch 004 | train_loss=0.1462 acc=0.828 f1=0.704 | valid_loss=0.1208 acc=0.909 f1=0.801 | lr=2.00e-03
# Epoch 005 | train_loss=0.1265 acc=0.857 f1=0.759 | valid_loss=0.0960 acc=0.909 f1=0.795 | lr=2.00e-03
# Epoch 006 | train_loss=0.1085 acc=0.859 f1=0.773 | valid_loss=0.1033 acc=0.871 f1=0.752 | lr=2.00e-03
# Epoch 007 | train_loss=0.0988 acc=0.875 f1=0.791 | valid_loss=0.0822 acc=0.917 f1=0.807 | lr=2.00e-03
# Epoch 008 | train_loss=0.1076 acc=0.847 f1=0.771 | valid_loss=0.0815 acc=0.886 f1=0.739 | lr=2.00e-03
# Epoch 009 | train_loss=0.0978 acc=0.887 f1=0.806 | valid_loss=0.0817 acc=0.924 f1=0.829 | lr=2.00e-03
# Epoch 010 | train_loss=0.0917 acc=0.895 f1=0.832 | valid_loss=0.0751 acc=0.917 f1=0.801 | lr=2.00e-03
# Epoch 011 | train_loss=0.0792 acc=0.897 f1=0.836 | valid_loss=0.0847 acc=0.902 f1=0.772 | lr=2.00e-03
# Epoch 012 | train_loss=0.0723 acc=0.906 f1=0.847 | valid_loss=0.0749 acc=0.924 f1=0.847 | lr=2.00e-03
# Epoch 013 | train_loss=0.0655 acc=0.920 f1=0.861 | valid_loss=0.0888 acc=0.864 f1=0.735 | lr=2.00e-03
# Epoch 014 | train_loss=0.0677 acc=0.920 f1=0.863 | valid_loss=0.0916 acc=0.894 f1=0.801 | lr=2.00e-03
# Epoch 015 | train_loss=0.0511 acc=0.937 f1=0.898 | valid_loss=0.0857 acc=0.909 f1=0.838 | lr=2.00e-03
# Epoch 016 | train_loss=0.0697 acc=0.916 f1=0.871 | valid_loss=0.0867 acc=0.924 f1=0.841 | lr=2.00e-03
# Epoch 017 | train_loss=0.0595 acc=0.934 f1=0.901 | valid_loss=0.0772 acc=0.909 f1=0.811 | lr=2.00e-03
# Epoch 018 | train_loss=0.0616 acc=0.920 f1=0.875 | valid_loss=0.0808 acc=0.932 f1=0.884 | lr=2.00e-03
# Epoch 019 | train_loss=0.0553 acc=0.927 f1=0.890 | valid_loss=0.0643 acc=0.917 f1=0.817 | lr=2.00e-03
# Epoch 020 | train_loss=0.0624 acc=0.923 f1=0.886 | valid_loss=0.0738 acc=0.924 f1=0.819 | lr=2.00e-03
# Epoch 021 | train_loss=0.0529 acc=0.930 f1=0.889 | valid_loss=0.0723 acc=0.902 f1=0.799 | lr=2.00e-03
# Epoch 022 | train_loss=0.0712 acc=0.897 f1=0.842 | valid_loss=0.0730 acc=0.924 f1=0.846 | lr=2.00e-03
# Epoch 023 | train_loss=0.0484 acc=0.934 f1=0.901 | valid_loss=0.0679 acc=0.917 f1=0.801 | lr=2.00e-03
# Epoch 024 | train_loss=0.0428 acc=0.946 f1=0.914 | valid_loss=0.0680 acc=0.924 f1=0.831 | lr=1.00e-03
# Epoch 025 | train_loss=0.0452 acc=0.941 f1=0.919 | valid_loss=0.0572 acc=0.932 f1=0.859 | lr=1.00e-03
# Epoch 026 | train_loss=0.0357 acc=0.953 f1=0.931 | valid_loss=0.0640 acc=0.932 f1=0.860 | lr=1.00e-03
# Epoch 027 | train_loss=0.0325 acc=0.946 f1=0.925 | valid_loss=0.0660 acc=0.932 f1=0.859 | lr=1.00e-03
# Epoch 028 | train_loss=0.0430 acc=0.951 f1=0.926 | valid_loss=0.0628 acc=0.917 f1=0.817 | lr=1.00e-03
# Epoch 029 | train_loss=0.0276 acc=0.956 f1=0.940 | valid_loss=0.0697 acc=0.917 f1=0.837 | lr=1.00e-03
# Epoch 030 | train_loss=0.0224 acc=0.962 f1=0.946 | valid_loss=0.0703 acc=0.932 f1=0.860 | lr=5.00e-04
# Epoch 031 | train_loss=0.0238 acc=0.960 f1=0.943 | valid_loss=0.0610 acc=0.932 f1=0.853 | lr=5.00e-04
# Epoch 032 | train_loss=0.0259 acc=0.962 f1=0.946 | valid_loss=0.0542 acc=0.932 f1=0.853 | lr=5.00e-04
# Epoch 033 | train_loss=0.0354 acc=0.949 f1=0.928 | valid_loss=0.0587 acc=0.932 f1=0.853 | lr=5.00e-04
# Epoch 034 | train_loss=0.0274 acc=0.962 f1=0.945 | valid_loss=0.0642 acc=0.924 f1=0.840 | lr=5.00e-04
# Epoch 035 | train_loss=0.0154 acc=0.979 f1=0.971 | valid_loss=0.0654 acc=0.932 f1=0.853 | lr=5.00e-04
# Epoch 036 | train_loss=0.0229 acc=0.965 f1=0.949 | valid_loss=0.0671 acc=0.924 f1=0.840 | lr=2.50e-04
# Epoch 037 | train_loss=0.0189 acc=0.976 f1=0.968 | valid_loss=0.0673 acc=0.932 f1=0.860 | lr=2.50e-04
# Epoch 038 | train_loss=0.0178 acc=0.969 f1=0.955 | valid_loss=0.0667 acc=0.917 f1=0.819 | lr=2.50e-04
# Early stopping triggered at epoch 38. Best f1=0.8843.
# Fold 2/5 | best F1=0.8843 | Accuracy=0.9318
# Epoch 001 | train_loss=0.2494 acc=0.695 f1=0.359 | valid_loss=0.2118 acc=0.788 f1=0.382 | lr=2.00e-03
# Epoch 002 | train_loss=0.2098 acc=0.740 f1=0.494 | valid_loss=0.1583 acc=0.795 f1=0.422 | lr=2.00e-03
# Epoch 003 | train_loss=0.1845 acc=0.758 f1=0.496 | valid_loss=0.1308 acc=0.864 f1=0.665 | lr=2.00e-03
# Epoch 004 | train_loss=0.1674 acc=0.787 f1=0.639 | valid_loss=0.1143 acc=0.856 f1=0.619 | lr=2.00e-03
# Epoch 005 | train_loss=0.1587 acc=0.779 f1=0.617 | valid_loss=0.1128 acc=0.871 f1=0.689 | lr=2.00e-03
# Epoch 006 | train_loss=0.1301 acc=0.843 f1=0.721 | valid_loss=0.1118 acc=0.886 f1=0.746 | lr=2.00e-03
# Epoch 007 | train_loss=0.1246 acc=0.841 f1=0.751 | valid_loss=0.0946 acc=0.856 f1=0.669 | lr=2.00e-03
# Epoch 008 | train_loss=0.1062 acc=0.883 f1=0.799 | valid_loss=0.0752 acc=0.924 f1=0.842 | lr=2.00e-03
# Epoch 009 | train_loss=0.1006 acc=0.873 f1=0.796 | valid_loss=0.0897 acc=0.879 f1=0.709 | lr=2.00e-03
# Epoch 010 | train_loss=0.0968 acc=0.876 f1=0.793 | valid_loss=0.0775 acc=0.909 f1=0.816 | lr=2.00e-03
# Epoch 011 | train_loss=0.0810 acc=0.895 f1=0.822 | valid_loss=0.0896 acc=0.894 f1=0.743 | lr=2.00e-03
# Epoch 012 | train_loss=0.0778 acc=0.899 f1=0.830 | valid_loss=0.0966 acc=0.871 f1=0.698 | lr=2.00e-03
# Epoch 013 | train_loss=0.0763 acc=0.911 f1=0.862 | valid_loss=0.1104 acc=0.818 f1=0.726 | lr=2.00e-03
# Epoch 014 | train_loss=0.1041 acc=0.850 f1=0.763 | valid_loss=0.0897 acc=0.924 f1=0.818 | lr=1.00e-03
# Epoch 015 | train_loss=0.0834 acc=0.895 f1=0.835 | valid_loss=0.0686 acc=0.947 f1=0.885 | lr=1.00e-03
# Epoch 016 | train_loss=0.0691 acc=0.915 f1=0.861 | valid_loss=0.0657 acc=0.924 f1=0.825 | lr=1.00e-03
# Epoch 017 | train_loss=0.0637 acc=0.925 f1=0.878 | valid_loss=0.0680 acc=0.917 f1=0.812 | lr=1.00e-03
# Epoch 018 | train_loss=0.0475 acc=0.923 f1=0.882 | valid_loss=0.0651 acc=0.939 f1=0.890 | lr=1.00e-03
# Epoch 019 | train_loss=0.0554 acc=0.920 f1=0.875 | valid_loss=0.0673 acc=0.932 f1=0.871 | lr=1.00e-03
# Epoch 020 | train_loss=0.0546 acc=0.925 f1=0.886 | valid_loss=0.0889 acc=0.886 f1=0.732 | lr=1.00e-03
# Epoch 021 | train_loss=0.0415 acc=0.946 f1=0.913 | valid_loss=0.0662 acc=0.939 f1=0.879 | lr=1.00e-03
# Epoch 022 | train_loss=0.0462 acc=0.941 f1=0.914 | valid_loss=0.0754 acc=0.924 f1=0.824 | lr=1.00e-03
# Epoch 023 | train_loss=0.0446 acc=0.936 f1=0.904 | valid_loss=0.0846 acc=0.902 f1=0.794 | lr=1.00e-03
# Epoch 024 | train_loss=0.0581 acc=0.923 f1=0.890 | valid_loss=0.0810 acc=0.894 f1=0.788 | lr=5.00e-04
# Epoch 025 | train_loss=0.0489 acc=0.925 f1=0.894 | valid_loss=0.0759 acc=0.909 f1=0.792 | lr=5.00e-04
# Epoch 026 | train_loss=0.0380 acc=0.955 f1=0.930 | valid_loss=0.0711 acc=0.917 f1=0.816 | lr=5.00e-04
# Epoch 027 | train_loss=0.0372 acc=0.951 f1=0.920 | valid_loss=0.0699 acc=0.909 f1=0.806 | lr=5.00e-04
# Epoch 028 | train_loss=0.0315 acc=0.953 f1=0.930 | valid_loss=0.0618 acc=0.932 f1=0.871 | lr=5.00e-04
# Epoch 029 | train_loss=0.0355 acc=0.941 f1=0.920 | valid_loss=0.0695 acc=0.932 f1=0.838 | lr=5.00e-04
# Epoch 030 | train_loss=0.0347 acc=0.949 f1=0.923 | valid_loss=0.0738 acc=0.924 f1=0.824 | lr=2.50e-04
# Epoch 031 | train_loss=0.0359 acc=0.953 f1=0.929 | valid_loss=0.0728 acc=0.939 f1=0.860 | lr=2.50e-04
# Epoch 032 | train_loss=0.0318 acc=0.951 f1=0.929 | valid_loss=0.0720 acc=0.932 f1=0.850 | lr=2.50e-04
# Epoch 033 | train_loss=0.0359 acc=0.960 f1=0.941 | valid_loss=0.0759 acc=0.932 f1=0.850 | lr=2.50e-04
# Epoch 034 | train_loss=0.0333 acc=0.944 f1=0.921 | valid_loss=0.0810 acc=0.924 f1=0.838 | lr=2.50e-04
# Epoch 035 | train_loss=0.0307 acc=0.967 f1=0.953 | valid_loss=0.0712 acc=0.939 f1=0.872 | lr=2.50e-04
# Epoch 036 | train_loss=0.0212 acc=0.976 f1=0.964 | valid_loss=0.0664 acc=0.932 f1=0.850 | lr=1.25e-04
# Epoch 037 | train_loss=0.0268 acc=0.967 f1=0.952 | valid_loss=0.0685 acc=0.939 f1=0.872 | lr=1.25e-04
# Epoch 038 | train_loss=0.0211 acc=0.969 f1=0.958 | valid_loss=0.0722 acc=0.924 f1=0.840 | lr=1.25e-04
# Early stopping triggered at epoch 38. Best f1=0.8896.
# Fold 3/5 | best F1=0.8896 | Accuracy=0.9394
# Epoch 001 | train_loss=0.2594 acc=0.638 f1=0.293 | valid_loss=0.2131 acc=0.773 f1=0.292 | lr=2.00e-03
# Epoch 002 | train_loss=0.1923 acc=0.772 f1=0.496 | valid_loss=0.1849 acc=0.765 f1=0.357 | lr=2.00e-03
# Epoch 003 | train_loss=0.1674 acc=0.784 f1=0.575 | valid_loss=0.1459 acc=0.826 f1=0.585 | lr=2.00e-03
# Epoch 004 | train_loss=0.1482 acc=0.808 f1=0.613 | valid_loss=0.1442 acc=0.833 f1=0.565 | lr=2.00e-03
# Epoch 005 | train_loss=0.1418 acc=0.815 f1=0.667 | valid_loss=0.1299 acc=0.864 f1=0.644 | lr=2.00e-03
# Epoch 006 | train_loss=0.1053 acc=0.862 f1=0.736 | valid_loss=0.1055 acc=0.848 f1=0.578 | lr=2.00e-03
# Epoch 007 | train_loss=0.1030 acc=0.871 f1=0.766 | valid_loss=0.1131 acc=0.856 f1=0.646 | lr=2.00e-03
# Epoch 008 | train_loss=0.0976 acc=0.887 f1=0.813 | valid_loss=0.1114 acc=0.848 f1=0.653 | lr=2.00e-03
# Epoch 009 | train_loss=0.0881 acc=0.889 f1=0.831 | valid_loss=0.1160 acc=0.848 f1=0.625 | lr=2.00e-03
# Epoch 010 | train_loss=0.0925 acc=0.894 f1=0.822 | valid_loss=0.1075 acc=0.841 f1=0.634 | lr=2.00e-03
# Epoch 011 | train_loss=0.0928 acc=0.876 f1=0.808 | valid_loss=0.0919 acc=0.894 f1=0.747 | lr=2.00e-03
# Epoch 012 | train_loss=0.0795 acc=0.906 f1=0.844 | valid_loss=0.1093 acc=0.856 f1=0.667 | lr=2.00e-03
# Epoch 013 | train_loss=0.0702 acc=0.925 f1=0.875 | valid_loss=0.1158 acc=0.871 f1=0.698 | lr=2.00e-03
# Epoch 014 | train_loss=0.0736 acc=0.904 f1=0.852 | valid_loss=0.0979 acc=0.871 f1=0.726 | lr=2.00e-03
# Epoch 015 | train_loss=0.0716 acc=0.913 f1=0.863 | valid_loss=0.0807 acc=0.879 f1=0.719 | lr=2.00e-03
# Epoch 016 | train_loss=0.0714 acc=0.916 f1=0.871 | valid_loss=0.0927 acc=0.871 f1=0.694 | lr=2.00e-03
# Epoch 017 | train_loss=0.0582 acc=0.916 f1=0.867 | valid_loss=0.0990 acc=0.902 f1=0.756 | lr=2.00e-03
# Epoch 018 | train_loss=0.0643 acc=0.925 f1=0.883 | valid_loss=0.0948 acc=0.856 f1=0.709 | lr=2.00e-03
# Epoch 019 | train_loss=0.0673 acc=0.922 f1=0.871 | valid_loss=0.0946 acc=0.871 f1=0.672 | lr=2.00e-03
# Epoch 020 | train_loss=0.0630 acc=0.920 f1=0.875 | valid_loss=0.0856 acc=0.864 f1=0.693 | lr=2.00e-03
# Epoch 021 | train_loss=0.0508 acc=0.916 f1=0.878 | valid_loss=0.0837 acc=0.902 f1=0.744 | lr=2.00e-03
# Epoch 022 | train_loss=0.0582 acc=0.929 f1=0.888 | valid_loss=0.0846 acc=0.879 f1=0.737 | lr=2.00e-03
# Epoch 023 | train_loss=0.0576 acc=0.915 f1=0.882 | valid_loss=0.0995 acc=0.894 f1=0.772 | lr=2.00e-03
# Epoch 024 | train_loss=0.0538 acc=0.930 f1=0.891 | valid_loss=0.1079 acc=0.879 f1=0.729 | lr=2.00e-03
# Epoch 025 | train_loss=0.0493 acc=0.955 f1=0.928 | valid_loss=0.1022 acc=0.902 f1=0.766 | lr=2.00e-03
# Epoch 026 | train_loss=0.0400 acc=0.956 f1=0.930 | valid_loss=0.0962 acc=0.909 f1=0.781 | lr=2.00e-03
# Epoch 027 | train_loss=0.0659 acc=0.934 f1=0.893 | valid_loss=0.0698 acc=0.902 f1=0.781 | lr=2.00e-03
# Epoch 028 | train_loss=0.0373 acc=0.951 f1=0.922 | valid_loss=0.0800 acc=0.909 f1=0.754 | lr=2.00e-03
# Epoch 029 | train_loss=0.0426 acc=0.944 f1=0.913 | valid_loss=0.0848 acc=0.909 f1=0.767 | lr=2.00e-03
# Epoch 030 | train_loss=0.0505 acc=0.930 f1=0.899 | valid_loss=0.0814 acc=0.894 f1=0.736 | lr=2.00e-03
# Epoch 031 | train_loss=0.0544 acc=0.943 f1=0.907 | valid_loss=0.0873 acc=0.902 f1=0.737 | lr=2.00e-03
# Epoch 032 | train_loss=0.0452 acc=0.943 f1=0.916 | valid_loss=0.0849 acc=0.924 f1=0.784 | lr=2.00e-03
# Epoch 033 | train_loss=0.0457 acc=0.944 f1=0.916 | valid_loss=0.0957 acc=0.902 f1=0.752 | lr=2.00e-03
# Epoch 034 | train_loss=0.0420 acc=0.946 f1=0.914 | valid_loss=0.0982 acc=0.886 f1=0.762 | lr=2.00e-03
# Epoch 035 | train_loss=0.0419 acc=0.958 f1=0.935 | valid_loss=0.0816 acc=0.909 f1=0.796 | lr=2.00e-03
# Epoch 036 | train_loss=0.0370 acc=0.953 f1=0.926 | valid_loss=0.0931 acc=0.902 f1=0.728 | lr=2.00e-03
# Epoch 037 | train_loss=0.0297 acc=0.970 f1=0.956 | valid_loss=0.0897 acc=0.917 f1=0.774 | lr=2.00e-03
# Epoch 038 | train_loss=0.0262 acc=0.967 f1=0.951 | valid_loss=0.0918 acc=0.902 f1=0.766 | lr=2.00e-03
# Epoch 039 | train_loss=0.0447 acc=0.944 f1=0.922 | valid_loss=0.1111 acc=0.909 f1=0.759 | lr=2.00e-03
# Epoch 040 | train_loss=0.0375 acc=0.955 f1=0.932 | valid_loss=0.0984 acc=0.879 f1=0.733 | lr=2.00e-03
# Epoch 041 | train_loss=0.0322 acc=0.956 f1=0.939 | valid_loss=0.1041 acc=0.894 f1=0.731 | lr=1.00e-03
# Epoch 042 | train_loss=0.0304 acc=0.956 f1=0.935 | valid_loss=0.0987 acc=0.902 f1=0.755 | lr=1.00e-03
# Epoch 043 | train_loss=0.0369 acc=0.943 f1=0.927 | valid_loss=0.0912 acc=0.902 f1=0.780 | lr=1.00e-03
# Epoch 044 | train_loss=0.0301 acc=0.963 f1=0.946 | valid_loss=0.0945 acc=0.902 f1=0.748 | lr=1.00e-03
# Epoch 045 | train_loss=0.0235 acc=0.965 f1=0.948 | valid_loss=0.1063 acc=0.909 f1=0.771 | lr=1.00e-03
# Epoch 046 | train_loss=0.0273 acc=0.960 f1=0.940 | valid_loss=0.0980 acc=0.917 f1=0.786 | lr=1.00e-03
# Epoch 047 | train_loss=0.0255 acc=0.963 f1=0.949 | valid_loss=0.0951 acc=0.924 f1=0.807 | lr=1.00e-03
# Epoch 048 | train_loss=0.0214 acc=0.974 f1=0.964 | valid_loss=0.0962 acc=0.924 f1=0.786 | lr=1.00e-03
# Epoch 049 | train_loss=0.0278 acc=0.965 f1=0.947 | valid_loss=0.0991 acc=0.917 f1=0.798 | lr=1.00e-03
# Epoch 050 | train_loss=0.0249 acc=0.974 f1=0.963 | valid_loss=0.1091 acc=0.924 f1=0.814 | lr=1.00e-03
# Epoch 051 | train_loss=0.0255 acc=0.963 f1=0.952 | valid_loss=0.1163 acc=0.917 f1=0.775 | lr=1.00e-03
# Epoch 052 | train_loss=0.0269 acc=0.969 f1=0.952 | valid_loss=0.0961 acc=0.917 f1=0.801 | lr=1.00e-03
# Epoch 053 | train_loss=0.0191 acc=0.977 f1=0.969 | valid_loss=0.0980 acc=0.917 f1=0.828 | lr=1.00e-03
# Epoch 054 | train_loss=0.0274 acc=0.963 f1=0.949 | valid_loss=0.1058 acc=0.909 f1=0.790 | lr=1.00e-03
# Epoch 055 | train_loss=0.0237 acc=0.969 f1=0.953 | valid_loss=0.0847 acc=0.924 f1=0.803 | lr=1.00e-03
# Epoch 056 | train_loss=0.0319 acc=0.958 f1=0.931 | valid_loss=0.0847 acc=0.894 f1=0.759 | lr=1.00e-03
# Epoch 057 | train_loss=0.0210 acc=0.972 f1=0.959 | valid_loss=0.0998 acc=0.909 f1=0.792 | lr=1.00e-03
# Epoch 058 | train_loss=0.0275 acc=0.970 f1=0.957 | valid_loss=0.1006 acc=0.909 f1=0.778 | lr=1.00e-03
# Epoch 059 | train_loss=0.0210 acc=0.967 f1=0.950 | valid_loss=0.0954 acc=0.909 f1=0.790 | lr=5.00e-04
# Epoch 060 | train_loss=0.0206 acc=0.979 f1=0.966 | valid_loss=0.0909 acc=0.917 f1=0.798 | lr=5.00e-04
# Epoch 061 | train_loss=0.0140 acc=0.976 f1=0.963 | valid_loss=0.0903 acc=0.917 f1=0.784 | lr=5.00e-04
# Epoch 062 | train_loss=0.0158 acc=0.976 f1=0.967 | valid_loss=0.0895 acc=0.909 f1=0.775 | lr=5.00e-04
# Epoch 063 | train_loss=0.0195 acc=0.977 f1=0.969 | valid_loss=0.0910 acc=0.917 f1=0.786 | lr=5.00e-04
# Epoch 064 | train_loss=0.0170 acc=0.976 f1=0.965 | valid_loss=0.0904 acc=0.924 f1=0.813 | lr=5.00e-04
# Epoch 065 | train_loss=0.0145 acc=0.972 f1=0.962 | valid_loss=0.0966 acc=0.917 f1=0.804 | lr=2.50e-04
# Epoch 066 | train_loss=0.0163 acc=0.977 f1=0.969 | valid_loss=0.0942 acc=0.909 f1=0.792 | lr=2.50e-04
# Epoch 067 | train_loss=0.0257 acc=0.969 f1=0.955 | valid_loss=0.0891 acc=0.909 f1=0.792 | lr=2.50e-04
# Epoch 068 | train_loss=0.0167 acc=0.983 f1=0.976 | valid_loss=0.0818 acc=0.917 f1=0.801 | lr=2.50e-04
# Epoch 069 | train_loss=0.0140 acc=0.977 f1=0.964 | valid_loss=0.0784 acc=0.917 f1=0.801 | lr=2.50e-04
# Epoch 070 | train_loss=0.0179 acc=0.976 f1=0.967 | valid_loss=0.0836 acc=0.932 f1=0.805 | lr=2.50e-04
# Epoch 071 | train_loss=0.0180 acc=0.974 f1=0.962 | valid_loss=0.0848 acc=0.932 f1=0.805 | lr=1.25e-04
# Epoch 072 | train_loss=0.0197 acc=0.979 f1=0.969 | valid_loss=0.0863 acc=0.932 f1=0.823 | lr=1.25e-04
# Epoch 073 | train_loss=0.0138 acc=0.979 f1=0.971 | valid_loss=0.0873 acc=0.947 f1=0.855 | lr=1.25e-04
# Epoch 074 | train_loss=0.0119 acc=0.981 f1=0.974 | valid_loss=0.0880 acc=0.947 f1=0.855 | lr=1.25e-04
# Epoch 075 | train_loss=0.0150 acc=0.979 f1=0.970 | valid_loss=0.0901 acc=0.939 f1=0.844 | lr=1.25e-04
# Epoch 076 | train_loss=0.0134 acc=0.979 f1=0.970 | valid_loss=0.0911 acc=0.932 f1=0.832 | lr=1.25e-04
# Epoch 077 | train_loss=0.0153 acc=0.983 f1=0.976 | valid_loss=0.0883 acc=0.939 f1=0.842 | lr=1.25e-04
# Epoch 078 | train_loss=0.0096 acc=0.990 f1=0.986 | valid_loss=0.0900 acc=0.932 f1=0.831 | lr=1.25e-04
# Epoch 079 | train_loss=0.0123 acc=0.986 f1=0.981 | valid_loss=0.0858 acc=0.924 f1=0.810 | lr=6.25e-05
# Epoch 080 | train_loss=0.0094 acc=0.986 f1=0.977 | valid_loss=0.0900 acc=0.932 f1=0.822 | lr=6.25e-05
# Epoch 081 | train_loss=0.0108 acc=0.986 f1=0.981 | valid_loss=0.0902 acc=0.932 f1=0.822 | lr=6.25e-05
# Epoch 082 | train_loss=0.0140 acc=0.986 f1=0.979 | valid_loss=0.0892 acc=0.932 f1=0.832 | lr=6.25e-05
# Epoch 083 | train_loss=0.0109 acc=0.988 f1=0.984 | valid_loss=0.0921 acc=0.917 f1=0.801 | lr=6.25e-05
# Epoch 084 | train_loss=0.0140 acc=0.991 f1=0.986 | valid_loss=0.0899 acc=0.932 f1=0.832 | lr=6.25e-05
# Epoch 085 | train_loss=0.0094 acc=0.990 f1=0.986 | valid_loss=0.0926 acc=0.932 f1=0.832 | lr=3.13e-05
# Epoch 086 | train_loss=0.0090 acc=0.986 f1=0.981 | valid_loss=0.0934 acc=0.932 f1=0.832 | lr=3.13e-05
# Epoch 087 | train_loss=0.0100 acc=0.984 f1=0.977 | valid_loss=0.0917 acc=0.932 f1=0.832 | lr=3.13e-05
# Epoch 088 | train_loss=0.0113 acc=0.981 f1=0.973 | valid_loss=0.0930 acc=0.932 f1=0.832 | lr=3.13e-05
# Epoch 089 | train_loss=0.0087 acc=0.988 f1=0.983 | valid_loss=0.0927 acc=0.932 f1=0.832 | lr=3.13e-05
# Epoch 090 | train_loss=0.0101 acc=0.983 f1=0.976 | valid_loss=0.0941 acc=0.932 f1=0.832 | lr=3.13e-05
# Epoch 091 | train_loss=0.0101 acc=0.988 f1=0.983 | valid_loss=0.0950 acc=0.924 f1=0.822 | lr=1.56e-05
# Epoch 092 | train_loss=0.0130 acc=0.979 f1=0.969 | valid_loss=0.0930 acc=0.932 f1=0.832 | lr=1.56e-05
# Epoch 093 | train_loss=0.0166 acc=0.974 f1=0.962 | valid_loss=0.0936 acc=0.932 f1=0.832 | lr=1.56e-05
# Early stopping triggered at epoch 93. Best f1=0.8552.
# Fold 4/5 | best F1=0.8552 | Accuracy=0.9470
# Epoch 001 | train_loss=0.2759 acc=0.652 f1=0.289 | valid_loss=0.2450 acc=0.773 f1=0.291 | lr=2.00e-03
# Epoch 002 | train_loss=0.2205 acc=0.740 f1=0.392 | valid_loss=0.1701 acc=0.795 f1=0.406 | lr=2.00e-03
# Epoch 003 | train_loss=0.1859 acc=0.758 f1=0.487 | valid_loss=0.1595 acc=0.818 f1=0.492 | lr=2.00e-03
# Epoch 004 | train_loss=0.1611 acc=0.807 f1=0.629 | valid_loss=0.1323 acc=0.826 f1=0.521 | lr=2.00e-03
# Epoch 005 | train_loss=0.1287 acc=0.845 f1=0.734 | valid_loss=0.1111 acc=0.879 f1=0.700 | lr=2.00e-03
# Epoch 006 | train_loss=0.1213 acc=0.857 f1=0.752 | valid_loss=0.1041 acc=0.879 f1=0.726 | lr=2.00e-03
# Epoch 007 | train_loss=0.1152 acc=0.868 f1=0.780 | valid_loss=0.0913 acc=0.886 f1=0.724 | lr=2.00e-03
# Epoch 008 | train_loss=0.0970 acc=0.876 f1=0.795 | valid_loss=0.1003 acc=0.871 f1=0.710 | lr=2.00e-03
# Epoch 009 | train_loss=0.0950 acc=0.894 f1=0.814 | valid_loss=0.0885 acc=0.864 f1=0.719 | lr=2.00e-03
# Epoch 010 | train_loss=0.0961 acc=0.875 f1=0.801 | valid_loss=0.1221 acc=0.856 f1=0.645 | lr=2.00e-03
# Epoch 011 | train_loss=0.1063 acc=0.889 f1=0.813 | valid_loss=0.0779 acc=0.894 f1=0.722 | lr=2.00e-03
# Epoch 012 | train_loss=0.0777 acc=0.911 f1=0.853 | valid_loss=0.0908 acc=0.917 f1=0.794 | lr=2.00e-03
# Epoch 013 | train_loss=0.0944 acc=0.894 f1=0.829 | valid_loss=0.0890 acc=0.902 f1=0.756 | lr=2.00e-03
# Epoch 014 | train_loss=0.0768 acc=0.908 f1=0.850 | valid_loss=0.0732 acc=0.894 f1=0.779 | lr=2.00e-03
# Epoch 015 | train_loss=0.0665 acc=0.925 f1=0.877 | valid_loss=0.0771 acc=0.924 f1=0.793 | lr=2.00e-03
# Epoch 016 | train_loss=0.0653 acc=0.929 f1=0.887 | valid_loss=0.0657 acc=0.909 f1=0.773 | lr=2.00e-03
# Epoch 017 | train_loss=0.0595 acc=0.911 f1=0.867 | valid_loss=0.0831 acc=0.909 f1=0.765 | lr=2.00e-03
# Epoch 018 | train_loss=0.0607 acc=0.920 f1=0.873 | valid_loss=0.0855 acc=0.909 f1=0.764 | lr=1.00e-03
# Epoch 019 | train_loss=0.0616 acc=0.943 f1=0.905 | valid_loss=0.0797 acc=0.924 f1=0.829 | lr=1.00e-03
# Epoch 020 | train_loss=0.0508 acc=0.941 f1=0.909 | valid_loss=0.0618 acc=0.924 f1=0.810 | lr=1.00e-03
# Epoch 021 | train_loss=0.0443 acc=0.939 f1=0.905 | valid_loss=0.0551 acc=0.924 f1=0.810 | lr=1.00e-03
# Epoch 022 | train_loss=0.0487 acc=0.936 f1=0.901 | valid_loss=0.0584 acc=0.947 f1=0.867 | lr=1.00e-03
# Epoch 023 | train_loss=0.0448 acc=0.929 f1=0.891 | valid_loss=0.0527 acc=0.932 f1=0.841 | lr=1.00e-03
# Epoch 024 | train_loss=0.0425 acc=0.944 f1=0.914 | valid_loss=0.0699 acc=0.932 f1=0.841 | lr=1.00e-03
# Epoch 025 | train_loss=0.0564 acc=0.936 f1=0.893 | valid_loss=0.0669 acc=0.939 f1=0.836 | lr=1.00e-03
# Epoch 026 | train_loss=0.0359 acc=0.956 f1=0.933 | valid_loss=0.0614 acc=0.939 f1=0.836 | lr=1.00e-03
# Epoch 027 | train_loss=0.0492 acc=0.934 f1=0.908 | valid_loss=0.0731 acc=0.932 f1=0.846 | lr=1.00e-03
# Epoch 028 | train_loss=0.0376 acc=0.958 f1=0.934 | valid_loss=0.0770 acc=0.932 f1=0.854 | lr=5.00e-04
# Epoch 029 | train_loss=0.0433 acc=0.936 f1=0.907 | valid_loss=0.0602 acc=0.924 f1=0.832 | lr=5.00e-04
# Epoch 030 | train_loss=0.0383 acc=0.953 f1=0.933 | valid_loss=0.0519 acc=0.939 f1=0.838 | lr=5.00e-04
# Epoch 031 | train_loss=0.0229 acc=0.976 f1=0.964 | valid_loss=0.0545 acc=0.939 f1=0.836 | lr=5.00e-04
# Epoch 032 | train_loss=0.0188 acc=0.979 f1=0.968 | valid_loss=0.0564 acc=0.924 f1=0.818 | lr=5.00e-04
# Epoch 033 | train_loss=0.0289 acc=0.958 f1=0.937 | valid_loss=0.0485 acc=0.939 f1=0.844 | lr=5.00e-04
# Epoch 034 | train_loss=0.0279 acc=0.965 f1=0.949 | valid_loss=0.0420 acc=0.947 f1=0.867 | lr=2.50e-04
# Epoch 035 | train_loss=0.0279 acc=0.970 f1=0.957 | valid_loss=0.0431 acc=0.962 f1=0.917 | lr=2.50e-04
# Epoch 036 | train_loss=0.0174 acc=0.972 f1=0.962 | valid_loss=0.0428 acc=0.955 f1=0.879 | lr=2.50e-04
# Epoch 037 | train_loss=0.0177 acc=0.983 f1=0.974 | valid_loss=0.0468 acc=0.955 f1=0.879 | lr=2.50e-04
# Epoch 038 | train_loss=0.0193 acc=0.972 f1=0.961 | valid_loss=0.0508 acc=0.955 f1=0.879 | lr=2.50e-04
# Epoch 039 | train_loss=0.0175 acc=0.977 f1=0.968 | valid_loss=0.0530 acc=0.955 f1=0.879 | lr=2.50e-04
# Epoch 040 | train_loss=0.0276 acc=0.958 f1=0.940 | valid_loss=0.0530 acc=0.947 f1=0.867 | lr=2.50e-04
# Epoch 041 | train_loss=0.0205 acc=0.976 f1=0.965 | valid_loss=0.0519 acc=0.939 f1=0.844 | lr=1.25e-04
# Epoch 042 | train_loss=0.0231 acc=0.962 f1=0.948 | valid_loss=0.0574 acc=0.947 f1=0.873 | lr=1.25e-04
# Epoch 043 | train_loss=0.0208 acc=0.979 f1=0.972 | valid_loss=0.0579 acc=0.947 f1=0.873 | lr=1.25e-04
# Epoch 044 | train_loss=0.0258 acc=0.970 f1=0.956 | valid_loss=0.0545 acc=0.947 f1=0.867 | lr=1.25e-04
# Epoch 045 | train_loss=0.0227 acc=0.981 f1=0.974 | valid_loss=0.0499 acc=0.947 f1=0.867 | lr=1.25e-04
# Epoch 046 | train_loss=0.0257 acc=0.969 f1=0.956 | valid_loss=0.0501 acc=0.947 f1=0.847 | lr=1.25e-04
# Epoch 047 | train_loss=0.0166 acc=0.988 f1=0.982 | valid_loss=0.0510 acc=0.947 f1=0.847 | lr=6.25e-05
# Epoch 048 | train_loss=0.0198 acc=0.976 f1=0.965 | valid_loss=0.0506 acc=0.947 f1=0.847 | lr=6.25e-05
# Epoch 049 | train_loss=0.0273 acc=0.970 f1=0.958 | valid_loss=0.0510 acc=0.955 f1=0.879 | lr=6.25e-05
# Epoch 050 | train_loss=0.0156 acc=0.981 f1=0.971 | valid_loss=0.0517 acc=0.955 f1=0.879 | lr=6.25e-05
# Epoch 051 | train_loss=0.0175 acc=0.977 f1=0.966 | valid_loss=0.0521 acc=0.955 f1=0.879 | lr=6.25e-05
# Epoch 052 | train_loss=0.0197 acc=0.976 f1=0.966 | valid_loss=0.0511 acc=0.955 f1=0.879 | lr=6.25e-05
# Epoch 053 | train_loss=0.0218 acc=0.974 f1=0.963 | valid_loss=0.0517 acc=0.955 f1=0.886 | lr=3.13e-05
# Epoch 054 | train_loss=0.0228 acc=0.974 f1=0.964 | valid_loss=0.0513 acc=0.955 f1=0.879 | lr=3.13e-05
# Epoch 055 | train_loss=0.0208 acc=0.967 f1=0.955 | valid_loss=0.0487 acc=0.955 f1=0.879 | lr=3.13e-05
# Early stopping triggered at epoch 55. Best f1=0.9174.
# Fold 5/5 | best F1=0.9174 | Accuracy=0.9621

# %%
def gather_results(source_names: List[str]) -> List[Dict]:
    collected: List[Dict] = []
    for name in source_names:
        if name in globals():
            value = globals()[name]
            if isinstance(value, list) and value:
                collected.extend(value)
    return collected


def build_summary_table(result_sources: List[str]) -> Tuple[pd.DataFrame, List[Dict]]:
    collected_results = gather_results(result_sources)
    if not collected_results:
        raise RuntimeError('No experiment results available. Run the training/sweep cells first.')

    summary_rows = []
    for res in collected_results:
        cfg = res['config']
        metrics = res['metrics']
        summary_rows.append({
            'run_name': res['run_name'],
            'fold': res.get('fold'),
            'rnn_type': cfg['rnn_type'],
            'bidirectional': cfg.get('bidirectional', False),
            'hidden_size': cfg['hidden_size'],
            'num_layers': cfg['num_layers'],
            'dropout': cfg['dropout'],
            'lr': cfg['lr'],
            'weight_decay': cfg.get('weight_decay', 0.0),
            'best_epoch': res['epoch'],
            'best_f1': res['best_f1'],
            'accuracy': metrics['accuracy'],
            'precision': metrics['precision'],
            'recall': metrics['recall'],
            'checkpoint': str(res['checkpoint_path']),
            'log_dir': str(LOG_DIR / res['run_name']),
            'is_cv': res.get('fold') is not None,
        })

    summary_df = pd.DataFrame(summary_rows)
    summary_df = summary_df.sort_values(by='best_f1', ascending=False).reset_index(drop=True)
    return summary_df, collected_results


RESULT_SOURCES = ['experiment_results', 'sweep_results', 'cv_results', 'auto_cv_results']
summary_table, all_results = build_summary_table(RESULT_SOURCES)
summary_table
# Out:
#        run_name  fold rnn_type  bidirectional  hidden_size  num_layers  \
# 0  GRU_BI_fold1   1.0      gru           True          128           2
# 1  GRU_BI_fold5   5.0      gru           True          128           2
# 2        GRU_BI   NaN      gru           True          128           2
# 3  GRU_BI_fold3   3.0      gru           True          128           2
# 4  GRU_BI_fold2   2.0      gru           True          128           2
# 5  GRU_BI_fold4   4.0      gru           True          128           2
# 6    GRU_SINGLE   NaN      gru          False          128           2
#
#    dropout     lr  weight_decay  best_epoch   best_f1  accuracy  precision  \
# 0      0.4  0.002        0.0001          46  0.985041  0.992481   0.974359
# 1      0.4  0.002        0.0001          35  0.917399  0.962121   0.954088
# 2      0.4  0.002        0.0001          51  0.889848  0.940299   0.850000
# 3      0.4  0.002        0.0001          18  0.889584  0.939394   0.892284
# 4      0.4  0.002        0.0001          18  0.884278  0.931818   0.882632
# 5      0.4  0.002        0.0001          73  0.855196  0.946970   0.906349
# 6      0.4  0.002        0.0001          45  0.823529  0.925373   0.810185
#
#      recall                                         checkpoint  \
# 0  0.996764  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...
# 1  0.886762  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...
# 2  0.943732  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...
# 3  0.889718  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...
# 4  0.913485  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...
# 5  0.827673  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...
# 6  0.857550  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...
#
#                                              log_dir  is_cv
# 0  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...   True
# 1  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...   True
# 2  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...  False
# 3  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...   True
# 4  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...   True
# 5  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...   True
# 6  /content/drive/MyDrive/[2025-2026]\ A2NDL/Chal...  False

# %%
for _, row in summary_table.iterrows():
    print(
        f"Run: {row['run_name']} | Model: {row['rnn_type'].upper()} | "
        f"Bidirectional: {row['bidirectional']} | F1: {row['best_f1']:.4f}"
    )
    print(f"  Logs: {row['log_dir']}")

# For combined TensorBoard (run on Colab / local):
# %tensorboard --logdir "{LOG_DIR.as_posix()}"
# Out:
# Run: GRU_BI_fold1 | Model: GRU | Bidirectional: True | F1: 0.9850
#   Logs: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/logs/GRU_BI_fold1
# Run: GRU_BI_fold5 | Model: GRU | Bidirectional: True | F1: 0.9174
#   Logs: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/logs/GRU_BI_fold5
# Run: GRU_BI | Model: GRU | Bidirectional: True | F1: 0.8898
#   Logs: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/logs/GRU_BI
# Run: GRU_BI_fold3 | Model: GRU | Bidirectional: True | F1: 0.8896
#   Logs: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/logs/GRU_BI_fold3
# Run: GRU_BI_fold2 | Model: GRU | Bidirectional: True | F1: 0.8843
#   Logs: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/logs/GRU_BI_fold2
# Run: GRU_BI_fold4 | Model: GRU | Bidirectional: True | F1: 0.8552
#   Logs: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/logs/GRU_BI_fold4
# Run: GRU_SINGLE | Model: GRU | Bidirectional: False | F1: 0.8235
#   Logs: /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/logs/GRU_SINGLE

# %%
cv_folds_df, cv_summary = summarize_cv_results(cv_results)
cv_summary
# Out:
#   rnn_type  bidirectional  f1_mean    f1_std  accuracy_mean  accuracy_std  \
# 0      gru           True   0.9063  0.049242       0.954557      0.023979
#
#    precision_mean  precision_std  recall_mean  recall_std
# 0        0.921942       0.040153      0.90288    0.061269

# %%
if 'all_results' not in globals() or not all_results:
    raise RuntimeError('No experiment results available. Run the training/sweep cells first.')

best_run = max(all_results, key=lambda x: x['best_f1'])
best_model = best_run['model']
best_history = best_run['history']
print(
    f"Selected best run: {best_run['run_name']} | "
    f"F1={best_run['best_f1']:.4f} | Accuracy={best_run['metrics']['accuracy']:.4f}"
)
# Out:
# Selected best run: GRU_BI_fold1 | F1=0.9850 | Accuracy=0.9925

# %%
def plot_history(history: Dict[str, List[float]], title: str = 'Learning Curves'):
    epochs = range(1, len(history['train_loss']) + 1)
    fig, axs = plt.subplots(1, 3, figsize=(18, 4))

    axs[0].plot(epochs, history['train_loss'], label='Train')
    axs[0].plot(epochs, history['valid_loss'], label='Valid')
    axs[0].set_title('Loss')
    axs[0].set_xlabel('Epoch')
    axs[0].legend()

    axs[1].plot(epochs, history['train_accuracy'], label='Train')
    axs[1].plot(epochs, history['valid_accuracy'], label='Valid')
    axs[1].set_title('Accuracy')
    axs[1].set_xlabel('Epoch')
    axs[1].legend()

    axs[2].plot(epochs, history['train_f1'], label='Train F1')
    axs[2].plot(epochs, history['valid_f1'], label='Valid F1')
    axs[2].set_title('Macro F1')
    axs[2].set_xlabel('Epoch')
    axs[2].legend()

    plt.suptitle(title)
    plt.tight_layout()
    plt.show()


plot_history(best_history, title=f"Learning Curves — {best_run['run_name']}")

# %%
best_preds = best_run['preds']
best_targets = best_run['targets']
print(f"Best validation macro F1: {best_run['best_f1']:.3f}")
print(
    classification_report(
        best_targets,
        best_preds,
        target_names=[IDX2LABEL[i] for i in range(NUM_CLASSES)],
    )
)

cf = confusion_matrix(best_targets, best_preds)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cf,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=[IDX2LABEL[i] for i in range(NUM_CLASSES)],
    yticklabels=[IDX2LABEL[i] for i in range(NUM_CLASSES)],
)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f"Validation Confusion Matrix — {best_run['run_name']}")
plt.show()
# Out:
# Best validation macro F1: 0.985
#               precision    recall  f1-score   support
#
#    high_pain       0.92      1.00      0.96        12
#     low_pain       1.00      1.00      1.00        18
#      no_pain       1.00      0.99      1.00       103
#
#     accuracy                           0.99       133
#    macro avg       0.97      1.00      0.99       133
# weighted avg       0.99      0.99      0.99       133

# %%
test_dataset = TimeSeriesDataset(
    X_test_np,
    labels=None,
    window_size=None,
    mode='test',
    high_pain_targets=HIGH_PAIN_IDX,
)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False, drop_last=False)

best_model.eval()
test_preds = []
best_config = best_run['config']
eval_window_size = best_config.get('eval_window_size', EVAL_WINDOW_SIZE)
eval_window_stride = best_config.get('eval_window_stride', EVAL_WINDOW_STRIDE)
eval_aggregation = best_config.get('eval_aggregation', EVAL_AGGREGATION)
with torch.no_grad():
    for inputs in test_loader:
        inputs = inputs.to(DEVICE)
        with autocast_context():
            logits = forward_with_sliding_windows(
                best_model,
                inputs,
                eval_window_size,
                eval_window_stride,
                eval_aggregation,
            )
        test_preds.append(torch.argmax(logits, dim=1).cpu().numpy())

test_preds = np.concatenate(test_preds)
test_labels = [IDX2LABEL[idx] for idx in test_preds]

submission = pd.DataFrame({
    'sample_index': pd.unique(X_test_raw['sample_index']),
    'label': test_labels,
})
submission_filename = OUTPUT_DIR / f"submission_{best_run['run_name'].lower()}.csv"
submission.to_csv(submission_filename, index=False)
print(f"Saved submission to {submission_filename}")
submission.head()
# Out:
# Saved submission to /content/drive/MyDrive/[2025-2026]\ A2NDL/Challenge/outputs/submission_gru_bi_fold1.csv
#    sample_index    label
# 0             0  no_pain
# 1             1  no_pain
# 2             2  no_pain
# 3             3  no_pain
# 4             4  no_pain

# %%
# %tensorboard --logdir "/content/drive/MyDrive/[2025-2026]\ AN2DL/Challenge/outputs/logs"
# Out:
# UsageError: Line magic function `%tensorboard` not found.

# %% [markdown]
# ## 8. Future Improvements and Extensions
#
# This section outlines potential enhancements and future work directions for improving the model performance and robustness.
#
# ### Next Steps
#
# - **Hyperparameter Optimization**: Expand `EXPERIMENT_CONFIGS` with random/grid search over hidden size, depth, dropout, learning rate, and scheduler parameters to automate hyperparameter tuning.
#
# - **Comprehensive Cross-Validation**: Use `run_cross_validation` on multiple configurations and compare aggregated metrics in `cv_summary`, exporting results (CSV/LaTeX) for the final report.
#
# - **Monitoring and Analysis**: Monitor all runs with `%tensorboard --logdir outputs/logs`, saving screenshots of key curves and comparing training times and resource usage.
#
# - **Advanced Regularization**: Integrate advanced regularization techniques such as:
#   - Label smoothing
#   - Temporal mixup
#   - Stochastic weight averaging
#   - Attention mechanisms or advanced pooling layers
#
# - **Model Ensembling**: Build ensembles from the best checkpoints (probability averaging or voting) before the final Kaggle submission to improve robustness and performance.
